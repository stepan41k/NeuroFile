# %%
import fitz
from PIL import Image
import io
import numpy as np
import cv2
import pytesseract
import re

def clean_text(s: str):
    return re.sub(r"\s+", " ", s.replace("\n", " ").strip())

def pil_from_pix(pix):
    img_bytes = pix.tobytes("png")
    return Image.open(io.BytesIO(img_bytes))

def to_cv2(img_pil):
    img = np.array(img_pil)
    if img.ndim == 2:
        return img
    return cv2.cvtColor(img, cv2.COLOR_RGB2BGR)

def ocr_image_region(cv_img, psm=6):
    config = f"--oem 3 --psm {psm}"
    pil = Image.fromarray(cv2.cvtColor(cv_img, cv2.COLOR_BGR2RGB))
    text = pytesseract.image_to_string(pil, lang="rus+eng", config=config)
    return clean_text(text)

def detect_table_regions(cv_img, scale=15, min_area=2000):
    gray = cv2.cvtColor(cv_img, cv2.COLOR_BGR2GRAY)
    gray = cv2.GaussianBlur(gray, (3,3),0)
    thr = cv2.adaptiveThreshold(gray,255,cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY_INV,15,9)

    horizontal = thr.copy()
    vertical = thr.copy()
    horiz_size = max(10, horizontal.shape[1]//scale)
    vert_size = max(8, vertical.shape[0]//scale)
    horiz_kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (horiz_size,1))
    vert_kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (1,vert_size))
    horizontal = cv2.dilate(cv2.erode(horizontal,horiz_kernel), horiz_kernel)
    vertical = cv2.dilate(cv2.erode(vertical,vert_kernel), vert_kernel)

    mask = cv2.add(horizontal, vertical)
    mask = cv2.dilate(mask, cv2.getStructuringElement(cv2.MORPH_RECT,(3,3)), iterations=2)

    contours,_ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    bboxes = []
    for cnt in contours:
        x,y,w,h = cv2.boundingRect(cnt)
        if w*h > min_area:
            bboxes.append((x,y,w,h))

    return sorted(bboxes, key=lambda b: b[1])  # сортировка по Y

def split_table_cells(region):
    gray = cv2.cvtColor(region, cv2.COLOR_BGR2GRAY)
    thr = cv2.adaptiveThreshold(gray,255,cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY_INV,15,9)
    h_kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (max(2, region.shape[1]//20),1))
    v_kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (1,max(2, region.shape[0]//20)))
    horizontal = cv2.dilate(cv2.erode(thr,h_kernel), h_kernel)
    vertical = cv2.dilate(cv2.erode(thr,v_kernel), v_kernel)
    inter = cv2.bitwise_and(horizontal, vertical)
    ys, xs = np.where(inter>0)

    if len(xs)<2 or len(ys)<2:
        return None

    def cluster_coords(coords, eps=10):
        coords = sorted(coords)
        clusters=[]
        cur=[coords[0]]
        for c in coords[1:]:
            if abs(c-cur[-1])<=eps:
                cur.append(c)
            else:
                clusters.append(int(sum(cur)/len(cur)))
                cur=[c]
        clusters.append(int(sum(cur)/len(cur)))
        return clusters

    xc = cluster_coords(list(xs))
    yc = cluster_coords(list(ys))

    if len(xc)<2 or len(yc)<2:
        return None

    table=[]
    for i in range(len(yc)-1):
        row=[]
        for j in range(len(xc)-1):
            x0,y0=xc[j],yc[i]
            x1,y1=xc[j+1],yc[i+1]
            row.append((x0,y0,x1-x0,y1-y0))
        table.append(row)
    return table

def parse_pdf(path, dpi=300):
    doc = fitz.open(path)
    output=[]

    for page in doc:
        pix = page.get_pixmap(dpi=dpi)
        pil = pil_from_pix(pix)
        cv_img = to_cv2(pil)

        # detect tables
        table_bboxes = detect_table_regions(cv_img)
        used_mask = np.zeros(cv_img.shape[:2], dtype=np.uint8)

        page_blocks=[]

        for x,y,w,h in table_bboxes:
            region = cv_img[y:y+h, x:x+w]
            cells = split_table_cells(region)
            if cells:
                table_rows=[]
                for row in cells:
                    row_texts=[]
                    for cell in row:
                        cx,cy,cw,ch=cell
                        cell_img=region[cy:cy+ch, cx:cx+cw]
                        txt = ocr_image_region(cell_img)
                        row_texts.append(txt)
                    table_rows.append(row_texts)
                page_blocks.append({"type":"table","content":table_rows})
            else:
                txt=ocr_image_region(region)
                page_blocks.append({"type":"table","content":[[txt]]})
            used_mask[y:y+h, x:x+w]=255

        # OCR for remaining text
        full_text = pytesseract.image_to_string(pil, lang="rus+eng", config="--oem 3 --psm 3")
        lines = [clean_text(l) for l in full_text.split("\n") if clean_text(l)]
        for line in lines:
            page_blocks.append({"type":"text","content":line})

        output.extend(page_blocks)

    doc.close()
    return output

# %%
data = parse_pdf("dataset/ПНАЭ Г-7-018-89.pdf", dpi=400)

# %%
data
# Out:
# [{'type': 'table', 'content': [['ии ии ии РУ ии']]},
#  {'type': 'table',
#   'content': [['ии РУРУУ И {_ ии иииииииииии РУ Ив ХГ["][["|']]},
#  {'type': 'text', 'content': 'Государственный комитет СССР по надзору'},
#  {'type': 'text',
#   'content': 'за безопасным ведением работ в атомной энергетике'},
#  {'type': 'text', 'content': 'ПРАВИЛА И НОРМЫ В АТОМНОЙ ЭНЕРГЕТИКЕ'},
#  {'type': 'text', 'content': 'УНИФИЦИРОВАННАЯ МЕТОДИКА КОНТРОЛЯ ОСНОВНЫХ'},
#  {'type': 'text',
#   'content': 'МАТЕРИАЛОВ (ПОЛУФАБРИКАТОВ), СВАРНЫХ СОЕДИНЕНИЙ И'},
#  {'type': 'text', 'content': 'НАПЛАВКИ ОБОРУДОВАНИЯ И ТРУБОПРОВОДОВ АЭУ'},
#  {'type': 'text', 'content': 'КАПИЛЛЯРНЫЙ КОНТРОЛЬ'},
#  {'type': 'text', 'content': 'ПНАЭ Г-7-018-89'},
#  {'type': 'text', 'content': 'Дата введения'},
#  {'type': 'text', 'content': '01.07.90.'},
#  {'type': 'text', 'content': 'Москва 1990'},
#  {'type': 'text',
#   'content': 'Обязательны для всех министерств, ведомств, организаций и предприятий, осуществ-'},
#  {'type': 'text',
#   'content': 'ляющих проектирование, конструирование, изготовление, монтаж и эксплуатацию оборудо-'},
#  {'type': 'text',
#   'content': 'вания и трубопроводов атомных энергетических установок.'},
#  {'type': 'text', 'content': 'СОДЕРЖАНИЕ'},
#  {'type': 'text', 'content': '1. ОБЩИЕ УКАЗАНИЯ................ ии 4'},
#  {'type': 'text',
#   'content': '2. ЧУВСТВИТЕЛЬНОСТЬ КАПИЛЛЯРНОГО КОНТРОЛЯ.............. ини ииинининиие 4'},
#  {'type': 'text',
#   'content': '3. ПОДГОТОВКА КОНТРОЛИРУЕМОЙ ПОВЕРХНОСТИ ...............илилилинилилилилиининилилиииилиилиинилилилиилилииннинини: 5'},
#  {'type': 'text',
#   'content': '4. МЕТОДИКА ПРОВЕДЕНИЯ КОНТРОЛЯ................ нии иииннинине 7'},
#  {'type': 'text',
#   'content': '5. ТРЕБОВАНИЯ К ОФОРМЛЕНИЮ ДОКУМЕНТАЦИИ................ нии 8'},
#  {'type': 'text',
#   'content': '6. ТРЕБОВАНИЯ БЕЗОПАСНОСТИ .............. нии 8'},
#  {'type': 'text', 'content': 'ПРИЛОЖЕНИЕ 1'},
#  {'type': 'text',
#   'content': 'ПРИГОТОВЛЕНИЕ ИНДИКАТОРНЫХ ПЕНЕТРАНТОВ, ПРОЯВИТЕЛЕЙ, ОЧИСТИТЕЛЕЙ................. 10'},
#  {'type': 'text', 'content': 'ПРИЛОЖЕНИЕ 2'},
#  {'type': 'text',
#   'content': 'ПРАВИЛА ХРАНЕНИЯ И ПРОВЕРКА КАЧЕСТВА ДЕФЕКТОСКОПИЧЕСКИХ МАТЕРИАЛОВ.......... 12'},
#  {'type': 'text', 'content': 'ПРИЛОЖЕНИЕ 3'},
#  {'type': 'text',
#   'content': 'ТЕХНОЛОГИЯ ИЗГОТОВЛЕНИЯ КОНТРОЛЬНЫХ ОБРАЗЦОВ ДЛЯ — ИСПЫТАНИЯ'},
#  {'type': 'text',
#   'content': 'ДЕФЕКТОСКОПИЧЕСКИХ НАБОРОВ.................... ини 13'},
#  {'type': 'text', 'content': 'ПРИЛОЖЕНИЕ 4'},
#  {'type': 'text',
#   'content': 'ПАСПОРТ НА КОНТРОЛЬНЫЙ ОБРАЗЕЦ №............лллилилилилиилилииинилилилиииилилилнинилилиииилиилиииииилиинилилииилининиий 14'},
#  {'type': 'text', 'content': 'ПРИЛОЖЕНИЕ 5'},
#  {'type': 'text',
#   'content': 'КОНТРОЛЬНЫЙ ОБРАЗЕЦ DOHA wu. .ecceccccscscssesescscscsessssesesucscscsssussssessucssscsvsucscssssessssesesusscsssesessssesesacssseeeeecees 15'},
#  {'type': 'text', 'content': 'ПРИЛОЖЕНИЕ 6'},
#  {'type': 'text',
#   'content': 'ПРИМЕНЕНИЕ ДЕФЕКТОСКОПИЧЕСКИХ МАТЕРИАЛОВ В АЭРОЗОЛЬНОЙ УПАКОВКЕ ............... 16'},
#  {'type': 'text', 'content': 'ПРИЛОЖЕНИЕ 7'},
#  {'type': 'text', 'content': 'ФОРМА ЖУРНАЛА .................. нии 17'},
#  {'type': 'text', 'content': 'ПРИЛОЖЕНИЕ 8'},
#  {'type': 'text',
#   'content': 'АТТЕСТАЦИЯ КОНТРОЛЕРОВ................. нии ииииенишини 19'},
#  {'type': 'text', 'content': 'ПРИЛОЖЕНИЕ 9'},
#  {'type': 'text',
#   'content': 'ОРГАНИЗАЦИЯ УЧАСТКА ДЛЯ ПРОВЕДЕНИЯ КАПИЛЛЯРНОГО КОНТРОЛЯ............... 1... еьеееииниииие 20'},
#  {'type': 'text', 'content': 'ПРИЛОЖЕНИЕ 10'},
#  {'type': 'text',
#   'content': 'ПЕРЕЧЕНЬ РЕАКТИВОВ И МАТЕРИАЛОВ, ПРИМЕНЯЕМЫХ ДЛЯ КАПИЛЛЯРНОГО'},
#  {'type': 'text', 'content': 'КОНТРОЛЯ............... ии 21'},
#  {'type': 'text', 'content': 'ПРИЛОЖЕНИЕ 11'},
#  {'type': 'text',
#   'content': 'ОРИЕНТИРОВОЧНЫЙ РАСХОД ДЕФЕКТОСКОПИЧЕСКИХ МАТЕРИАЛОВ В РАСЧЕТЕ HA 1 М"'},
#  {'type': 'text',
#   'content': 'КОНТРОЛИРУЕМОЙ ПОВЕРХНОСТИ ................. ниши 22'},
#  {'type': 'text',
#   'content': 'ОРИЕНТИРОВОЧНЫЙ РАСХОД ДЕФЕКТОСКОПИЧЕСКИХ ПРИНАДЛЕЖНОСТЕЙ В РАСЧЕТЕ'},
#  {'type': 'text',
#   'content': 'НА 10 M* КОНТРОЛИРУЕМОЙ TOBEPXHOCTHA ........ccccccscssssssessssesesssscscscsscscscssscscscssucscsesesecsssesesusscseseeesssseseeseeeees 22'},
#  {'type': 'text',
#   'content': 'Настоящий документ устанавливает классы чувствительности капиллярного контроля,'},
#  {'type': 'text',
#   'content': 'технологическую последовательность операций при контроле, рецептуру наборов дефекто-'},
#  {'type': 'text',
#   'content': 'скопических материалов, требования к контрольным образцам. Методика распространяется'},
#  {'type': 'text',
#   'content': 'на сварные соединения и наплавку, контролируемые в соответствии с требованиями ПНАЭ'},
#  {'type': 'text',
#   'content': 'Г-7-010-89 "Оборудование и трубопроводы атомных энергетических установок. Сварные со-'},
#  {'type': 'text',
#   'content': 'единения и наплавки. Правила контроля", и на основные материалы (полуфабрикаты), кон-'},
#  {'type': 'text',
#   'content': 'тролируемые в соответствии с требованиями стандартов и технических условий.'},
#  {'type': 'text', 'content': '1. ОБЩИЕ УКАЗАНИЯ'},
#  {'type': 'text',
#   'content': '1.1. Капиллярный контроль позволяет обнаружить дефекты, выходящие на поверх-'},
#  {'type': 'text',
#   'content': 'ность: трещины, поры, раковины, непровары, межкристаллитную коррозию и другие не-'},
#  {'type': 'text', 'content': 'сплошности.'},
#  {'type': 'text',
#   'content': '1.2. Поверхностные дефекты обнаруживаются по ярко окрашенным или светящимся'},
#  {'type': 'text',
#   'content': 'индикаторным следам, которые образуются на проявляющем покрытии (проявителе) в мес-'},
#  {'type': 'text', 'content': 'тах расположения несплошностей.'},
#  {'type': 'text',
#   'content': '1.3. Выявление дефектов, имеющих ширину раскрытия более 0,5 мм, капиллярными'},
#  {'type': 'text', 'content': 'методами контроля не гарантируется.'},
#  {'type': 'text',
#   'content': '1.4. Контролю капиллярными методами подлежат поверхности изделия, принятые по'},
#  {'type': 'text',
#   'content': 'результатам визуального контроля в соответствии с требованиями действующей норматив-'},
#  {'type': 'text',
#   'content': 'ной документации. Для сварных соединений и наплавки - в соответствии с требованиями'},
#  {'type': 'text',
#   'content': 'ПНАЭ Г-7-010-89 "Оборудование и трубопроводы атомных энергетических установок.'},
#  {'type': 'text',
#   'content': 'Сварные соединения и наплавки. Правила контроля", для основных материалов (полуфабри-'},
#  {'type': 'text',
#   'content': 'катов) - в соответствии с требованиями нормативно-технической документации (стандартов,'},
#  {'type': 'text',
#   'content': 'технических условий, конструкторской документации).'},
#  {'type': 'text',
#   'content': '1.5. При капиллярном контроле контролируемая зона сварных соединений определяет-'},
#  {'type': 'text', 'content': 'ся требованиями ПНАЭ Г-7-010-89.'},
#  {'type': 'text',
#   'content': '1.6. Капиллярный контроль проводится перед проведением контроля другими метода-'},
#  {'type': 'text',
#   'content': 'ми (ультразвуковым, магнитопорошковым). В случае проведения капиллярного контроля по-'},
#  {'type': 'text',
#   'content': 'сле магнитопорошкового объект подлежит размагничиванию.'},
#  {'type': 'text',
#   'content': '1.7. При проведении капиллярного контроля применяют аппаратуру в соответствии с'},
#  {'type': 'text', 'content': 'требованиями ГОСТ 18442-80, ГОСТ 23349-78.'},
#  {'type': 'text',
#   'content': '1.8. Настоящий документ устанавливает методику капиллярного контроля при темпе-'},
#  {'type': 'text',
#   'content': 'ратуре от -40 до +40°C и относительной влажности не более 90%.'},
#  {'type': 'text',
#   'content': '1.9. При необходимости дополнения настоящего документа наборами дефектоскопиче-'},
#  {'type': 'text',
#   'content': 'ских материалов, составы которых документом не предусмотрены, должно выполняться сле-'},
#  {'type': 'text',
#   'content': 'дующее требование: "В дефектоскопических материалах, используемых при капиллярном'},
#  {'type': 'text',
#   'content': 'контроле сварных соединений из аустенитных сталей или сплавов на железоникелевой и ни-'},
#  {'type': 'text',
#   'content': 'келевой основе, содержание хлора и серы не должно превышать значений, установленных'},
#  {'type': 'text',
#   'content': 'стандартами или нормативно-техническими документами на эти материалы, но в любом слу-'},
#  {'type': 'text',
#   'content': 'чае содержание хлора и серы в сухом остатке, полученном после выпаривания 100 г мате-'},
#  {'type': 'text',
#   'content': 'риала (пенетранта), не должно превышать 1% (для каждого из указанных элементов) ".'},
#  {'type': 'text',
#   'content': '1.10. Применение других наборов дефектоскопических материалов должно быть согла-'},
#  {'type': 'text',
#   'content': 'совано с головной отраслевой материаловедческой организацией, при этом чувствительность'},
#  {'type': 'text',
#   'content': 'контроля данным составом должна определяться с вероятностью 0,95.'},
#  {'type': 'text',
#   'content': '1.11. Нормы расхода дефектоскопических материалов установлены справочным при-'},
#  {'type': 'text', 'content': 'ложением 11.'},
#  {'type': 'text', 'content': '2. ЧУВСТВИТЕЛЬНОСТЬ КАПИЛЛЯРНОГО КОНТРОЛЯ'},
#  {'type': 'text',
#   'content': '2.1. Чувствительность контроля определяется средним раскрытием неразветвленной'},
#  {'type': 'table',
#   'content': [['Класс чувстви- тельности',
#     'Чувствительность контроля (ширина раскрытия), мкм',
#     'Метод кон- троля',
#     "Набор дефекто- скопических материалов *'",
#     'Услови',
#     'я контроля'],
#    ['—',
#     'о',
#     'о',
#     'о',
#     'Интервал темпера- тур, °С',
#     'Состояние контролируе- мой поверхно- сти R,, мкм *°'],
#    ['',
#     '',
#     'Люминес- центный Цветной Ш Ш',
#     '[Ио Мюг Шо СИ Mio2 Шо? I-Vo02 НМ Ша ИЛИ [ГИ НМ Шоз',
#     '+8...+40 +8...+40 +8...+40 +8...+40',
#     '< 20 < 20 < 20 < 20'],
#    ['',
#     'От | до 10',
#     'Люминес- центный Цветной Ш Ш Ш Ш Ш Ш',
#     'П-Ио> Мог Шо ПП-И›з Mo; Шо ПП-И›о5 M203 Moo1 П-Иж Mao4 202 П-И›о7 М»о5 L203 П-И›» НМ»»› По или П-И› HM 92 Поз',
#     '-40...+8 -40...+8 +8...+40 +8...+40 +8...+40 +8...+40 +8...+40 +8...+40 +8...+40',
#     '< 20 < 20 < 20 < 20 < 20 < 20 < 20 < 40 < 40']]},
#  {'type': 'text', 'content': 'трещины длиной не менее 3 мм.'},
#  {'type': 'text',
#   'content': '2.2. В зависимости от ширины раскрытия минимальной из выявляемых единичных'},
#  {'type': 'text',
#   'content': 'трещин установлены три класса чувствительности, указанные в таблице.'},
#  {'type': 'text',
#   'content': '2.3. Чувствительность контроля, соответствующая определенному классу, обеспечива-'},
#  {'type': 'text',
#   'content': 'ется применением конкретных наборов дефектоскопических материалов при соблюдении'},
#  {'type': 'text',
#   'content': 'технологической последовательности операций контроля и требований к подготовке поверх-'},
#  {'type': 'text', 'content': 'ности.'},
#  {'type': 'text',
#   'content': '2.4. Класс чувствительности и объем контроля устанавливает проектная (конструктор-'},
#  {'type': 'text',
#   'content': 'ская) организация в соответствии с действующей технической документацией. Нормы при-'},
#  {'type': 'text',
#   'content': 'емки по результатам контроля должны соответствовать : для сварных соединений и наплавки'},
#  {'type': 'text',
#   'content': '- требованиям ПНАЭ Г-7-010-89 "Оборудование и трубопроводы атомных энергетических'},
#  {'type': 'text',
#   'content': 'установок. Сварные соединения и наплавки. Правила контроля", для основного материала'},
#  {'type': 'text',
#   'content': '(полуфабрикатов) - требованиям нормативно-технической документации (стандартам, тех-'},
#  {'type': 'text',
#   'content': 'ническим условиям, конструкторской документации).'},
#  {'type': 'text',
#   'content': '2.5. Состав наборов дефектоскопических материалов указан в таблице. Технология их'},
#  {'type': 'text',
#   'content': 'приготовления изложена в приложении 1, проверка качества - в приложении 2.'},
#  {'type': 'text',
#   'content': '2.6. Конкретный набор материалов для проведения контроля по установленному классу'},
#  {'type': 'text',
#   'content': 'чувствительности выбирает предприятие-изготовитель, пользуясь таблицей.'},
#  {'type': 'text', 'content': '3. ПОДГОТОВКА КОНТРОЛИРУЕМОЙ ПОВЕРХНОСТИ'},
#  {'type': 'text',
#   'content': '3.1. Необходимость зачистки устанавливается проведением выборочного контроля в'},
#  {'type': 'text',
#   'content': 'местах плохого состояния необработанной поверхности (наличие ржавчины, окалины, шла-'},
#  {'type': 'text', 'content': 'ков, подрезов, резких западаний).'},
#  {'type': 'text',
#   'content': 'Классы чувствительности капиллярных методов контроля'},
#  {'type': 'text',
#   'content': 'Класс Чувствительность Метод кон- Набор дефекто- Условия контроля'},
#  {'type': 'text', 'content': 'чувстви- | контроля (ширина скопических'},
#  {'type': 'text', 'content': '1'},
#  {'type': 'text', 'content': 'тельности | раскрытия), мкм материалов *'},
#  {'type': 'text', 'content': 'Состояние'},
#  {'type': 'text', 'content': 'Интервал | контролируе-'},
#  {'type': 'text', 'content': 'темпера- | мой поверхно-'},
#  {'type': 'text', 'content': 'тур, °C сти R,, мкм *°'},
#  {'type': 'text', 'content': 'Люминес- Ио Mio: Шо'},
#  {'type': 'text', 'content': 'центный [И М> Шо'},
#  {'type': 'text', 'content': 'Цветной 1-2 HMyo1 Iho'},
#  {'type': 'text', 'content': 'ИЛИ'},
#  {'type': 'text', 'content': 'Ио HM jo) Шоз'},
#  {'type': 'text', 'content': 'П От 1 AO 10 Люминес- П-И,го2 M501 Пот'},
#  {'type': 'text', 'content': 'центный ПП-И›з Mo;'},
#  {'type': 'text', 'content': 'Цветной Шо'},
#  {'type': 'text', 'content': 'ПП-И›о5 M203'},
#  {'type': 'text', 'content': 'Moo1'},
#  {'type': 'text', 'content': 'П-Иж Mao4 202'},
#  {'type': 'text', 'content': 'П-Иро7 Moos E1203'},
#  {'type': 'text', 'content': 'TI-Mo92 НМ»»›'},
#  {'type': 'text', 'content': 'По uM'},
#  {'type': 'text', 'content': 'П-Иж› НМ»'},
#  {'type': 'text', 'content': 'Поз'},
#  {'type': 'table',
#   'content': [['Класс чувстви- тельности',
#     'Чувствительность контроля (ширина раскрытия), мкм',
#     'Метод кон- троля',
#     "Набор дефекто- скопических материалов *'",
#     'Услови',
#     'я контроля'],
#    ['Po', 'Po', 'PM', 'Po', 'Po', 'ааа'],
#    ['',
#     '',
#     'Цветной "',
#     'Ш-Ило Mio: Шо Ш-И» НМьо› (Мо) Шо (Поз)',
#     '+8...+40 +8...+40',
#     '> 20 Необработан- ная или обра- ботанная при наличии ок- рашенного фона, не пре- вышающего допустимый *°']]},
#  {'type': 'text',
#   'content': 'Класс Чувствительность Метод кон- Набор дефекто- Условия контроля'},
#  {'type': 'text', 'content': 'чувстви- | контроля (ширина троля скопических'},
#  {'type': 'text', 'content': '1'},
#  {'type': 'text', 'content': 'тельности | раскрытия), мкм материалов *'},
#  {'type': 'text', 'content': '10 и более Ш-И» Мио По > 20'},
#  {'type': 'text', 'content': 'Ш-И» HM Необработан-'},
#  {'type': 'text', 'content': '(Мог) Lior (Шоз) ная или обра-'},
#  {'type': 'text', 'content': 'ботанная при'},
#  {'type': 'text', 'content': 'наличии ок-'},
#  {'type': 'text', 'content': 'рашенного'},
#  {'type': 'text', 'content': 'фона, не пре-'},
#  {'type': 'text', 'content': 'вышающего'},
#  {'type': 'text', 'content': 'допустимый *°'},
#  {'type': 'text',
#   'content': "*' Запись набора материалов расшифровывается следующим образом: римская цифра обозначает класс"},
#  {'type': 'text',
#   'content': 'чувствительности; первая цифра индекса у индикаторного пенетранта И - метод контроля (1-люминесцентный,'},
#  {'type': 'text',
#   'content': '2 - цветной); вторая и третья цифры - номер по порядку (при данном методе контроля); первая цифра индекса у'},
#  {'type': 'text',
#   'content': 'очистителя М и проявителя П обозначает применимость по наиболее высокому классу чувствительности, вто-'},
#  {'type': 'text',
#   'content': 'рая и третья цифры - номер по порядку. Буква Н (после обозначения индикаторного пенетранта) указывает на'},
#  {'type': 'text',
#   'content': 'способ контроля набором данного состава в режиме накопления красителя (разд. 4).'},
#  {'type': 'text', 'content': '2'},
#  {'type': 'text',
#   'content': '*^ Следует читать: необработанная при отсутствии в процессе выборочного контроля светящегося или'},
#  {'type': 'text',
#   'content': 'окрашенного фона или обработанная до шероховатости поверхности по параметру В, < 20 мкм.'},
#  {'type': 'text', 'content': '3'},
#  {'type': 'text',
#   'content': '*° Допустимым является фон, интенсивность окраски которого не превышает интенсивности окраски'},
#  {'type': 'text', 'content': 'контрольного образца фона (приложение 5).'},
#  {'type': 'text',
#   'content': '3.2. Зачистка (например, шлифованием) необработанной поверхности требуется при'},
#  {'type': 'text',
#   'content': 'образовании в процессе контроля светящегося или окрашенного фона.'},
#  {'type': 'text',
#   'content': '3.3. Поверхность, подлежащая контролю, должна быть обезжирена органическим рас-'},
#  {'type': 'text',
#   'content': 'творителем (например, бензином, ацетоном) с последующей протиркой чистой сухой безвор-'},
#  {'type': 'text', 'content': 'совой тканью типа мадаполам.'},
#  {'type': 'text',
#   'content': 'При невозможности использования органических растворителей (например, при кон-'},
#  {'type': 'text',
#   'content': 'троле внутри конструкции) обезжиривание следует проводить 5%-ным водным раствором'},
#  {'type': 'text',
#   'content': 'порошкообразного синтетического моющего средства (СМС) любой марки.'},
#  {'type': 'text',
#   'content': '3.4. Полости несплошностей должны быть очищены одним из следующих способов.'},
#  {'type': 'text',
#   'content': '3.4.1. Прогреть поверхностный слой изделия при температуре 100-120°C не менее 20'},
#  {'type': 'text', 'content': 'МИН.'},
#  {'type': 'text',
#   'content': '3.4.2. Нанести на поверхность проявитель П1о! или Шоз, выдержать не менее 20 мин по-'},
#  {'type': 'text',
#   'content': 'сле высыхания, затем удалить сухой бязью, губкой, щеткой или пылесосом.'},
#  {'type': 'text',
#   'content': 'Проявитель Поз следует удалять, если далее выполняется контроль в режиме накопле-'},
#  {'type': 'text', 'content': 'ния красителя.'},
#  {'type': 'text',
#   'content': '3.5. Промежуток времени между окончанием подготовки изделий к контролю и нане-'},
#  {'type': 'text',
#   'content': 'сением индикаторного пенетранта не должен превышать 30 мин. В течение этого времени'},
#  {'type': 'text',
#   'content': 'должна быть исключена возможность конденсации атмосферной влаги на контролируемой'},
#  {'type': 'text',
#   'content': 'поверхности, а также попадание на нее различных жидкостей и загрязнений.'},
#  {'type': 'text',
#   'content': '3.6. Операции по пп. 3.4.1 и 3.4.2 допускается не проводить для деталей и изделий, по-'},
#  {'type': 'text',
#   'content': 'ступивших на контроль после сварки, термической обработки и сухой механической обра-'},
#  {'type': 'text', 'content': 'ботки при соблюдении требований п. 3.5.'},
#  {'type': 'text',
#   'content': '3.7. После обезжиривания поверхности 5%-ным раствором СМС по п. 3.3 полости не-'},
#  {'type': 'text',
#   'content': 'сплошностей должны быть очищены согласно п. 3.4.2.'},
#  {'type': 'text',
#   'content': '3.8. При контроле в условиях низких температур от -40 до +8°C контролируемую по-'},
#  {'type': 'text',
#   'content': 'верхность следует обезжирить бензином, затем осушить спиртом.'},
#  {'type': 'text',
#   'content': '3.9. Если поверхность сварного соединения перед контролем подвергалась травлению,'},
#  {'type': 'text',
#   'content': 'то травящий состав должен быть удален путем нейтрализации 10 -15%-ным раствором каль-'},
#  {'type': 'text',
#   'content': 'цинированной соды с последующей промывкой водой и просушиванием воздухом, подогре-'},
#  {'type': 'text',
#   'content': 'тым воздухом (температуры не менее 40°С) или протиркой сухой безворсовой тканью типа'},
#  {'type': 'text',
#   'content': 'мадаполам, после чего полости дефектов должны быть очищены по п. 3.4.'},
#  {'type': 'text',
#   'content': '3.10. Подготовка изделий к контролю путем механической очистки и прогревом, а так-'},
#  {'type': 'text',
#   'content': 'же окончательная очистка изделий после проведения контроля не входят в обязанности де-'},
#  {'type': 'text', 'content': 'фектоскописта.'},
#  {'type': 'text',
#   'content': '3.11. При проведении контроля в вечернее и ночное время возможно снижение внима-'},
#  {'type': 'text', 'content': 'ния дефектоскопистов.'},
#  {'type': 'text', 'content': '4. МЕТОДИКА ПРОВЕДЕНИЯ КОНТРОЛЯ'},
#  {'type': 'text', 'content': '4.1. Нанесение индикаторного пенетранта.'},
#  {'type': 'text',
#   'content': '4.1.1. Индикаторный пенетрант наносят на подготовленную согласно разд. 2 контроли-'},
#  {'type': 'text',
#   'content': 'руемую поверхность кистью, губкой, окунанием, а также с помощью пульверизатора-'},
#  {'type': 'text',
#   'content': 'краскораспылителя или аэрозольного баллона (кроме И»о-). Пенетрант выдерживают Ha по-'},
#  {'type': 'text',
#   'content': 'верхности не менее 5 мин, не допуская его высыхания, после чего его следует удалить.'},
#  {'type': 'text',
#   'content': 'Составы индикаторных пенетрантов приведены в обязательном приложении 1. Реко-'},
#  {'type': 'text',
#   'content': 'мендации по применению дефектоскопических материалов в аэрозольных баллонах изложе-'},
#  {'type': 'text', 'content': 'ны в приложении 6 (рекомендуемом).'},
#  {'type': 'text',
#   'content': '4.1.2. В случае контроля в режиме накопления красителя на подготовленную согласно'},
#  {'type': 'text',
#   'content': 'разд. 3 поверхность наносят проявитель Поз (если он не был нанесен при подготовке по-'},
#  {'type': 'text',
#   'content': 'верхности) и выдерживают его на поверхности не менее 20 мин (до высыхания).'},
#  {'type': 'text',
#   'content': 'На слой проявителя Поз наносят индикаторный пенетрант И>02, выдерживают Ha по-'},
#  {'type': 'text',
#   'content': 'верхности до высыхания. Наносят пенетрант M292 второй раз и выдерживают на поверхности'},
#  {'type': 'text',
#   'content': 'не менее | мин, не допуская высыхания, после чего его следует удалить.'},
#  {'type': 'text', 'content': '4.2. Удаление индикаторного пенетранта.'},
#  {'type': 'text',
#   'content': '4.2.1. Индикаторный пенетрант удаляют влажной безворсовой тканью типа мадаполам,'},
#  {'type': 'text',
#   'content': 'щеткой, губкой и т.п., смоченными очистителем, а также с помощью пульверизатора-'},
#  {'type': 'text',
#   'content': 'краскораспылителя или аэрозольного баллона (кроме Мооз).'},
#  {'type': 'text',
#   'content': 'Составы очистителей приведены в приложении 1 (обязательном).'},
#  {'type': 'text',
#   'content': '4.2.2. При контроле в условиях низких температур от -40 до +8°С индикаторный пенет-'},
#  {'type': 'text',
#   'content': 'рант с контролируемой поверхности удаляют безворсовой тканью типа мадаполам, смочен-'},
#  {'type': 'text', 'content': 'ной в этиловом спирте.'},
#  {'type': 'text',
#   'content': '4.2.3. Удаляют индикаторный пенетрант до полного отсутствия свечения или окрашен-'},
#  {'type': 'text',
#   'content': 'ности поверхности. Полноту удаления индикаторного пенетранта следует определять визу-'},
#  {'type': 'text',
#   'content': 'ально. Избыток очистителя необходимо удалить с контролируемой поверхности влажной'},
#  {'type': 'text', 'content': 'безворсовой тканью.'},
#  {'type': 'text',
#   'content': '4.2.4. При удалении индикаторного пенетранта W295 очистителем Мооз (водой) интен-'},
#  {'type': 'text',
#   'content': 'сивность удаления пенетранта и время контакта очистителя с поверхностью должны быть'},
#  {'type': 'text',
#   'content': 'минимальными, чтобы исключить вымывание пенетранта из несплошностей.'},
#  {'type': 'text', 'content': '4.3. Нанесение и сушка проявителя.'},
#  {'type': 'text',
#   'content': '4.3.1. Проявитель наносится тонким слоем, обеспечивающим выявляемость на соответ-'},
#  {'type': 'text',
#   'content': 'ствующем контрольном образце, с помощью пульверизатора-краскораспылителя или аэро-'},
#  {'type': 'text',
#   'content': 'зольного баллона (кроме П2о1), мягкой кистью, губкой или окунанием сразу после очистки'},
#  {'type': 'text', 'content': 'контролируемой поверхности от пенетранта.'},
#  {'type': 'text', 'content': 'Составы проявителей приведены в таблице.'},
#  {'type': 'text',
#   'content': '4.3.2. Сушку проявителя следует проводить за счет естественного испарения или горя-'},
#  {'type': 'text', 'content': 'чим воздухом с температурой +60°C.'},
#  {'type': 'text',
#   'content': '4.3.3. При контроле в условиях низких температур для сушки дополнительно могут'},
#  {'type': 'text',
#   'content': 'быть применены отражательные электронагревательные приборы.'},
#  {'type': 'text', 'content': '4.4. Осмотр контролируемой поверхности.'},
#  {'type': 'text',
#   'content': '4.4.1. Осмотр контролируемой поверхности проводится через 20 мин после высыхания'},
#  {'type': 'text',
#   'content': 'проявителя. При осмотре допускается использовать лупу до 7-кратного увеличения.'},
#  {'type': 'text',
#   'content': '4.4.2. При выполнении капиллярного контроля освещенность и облученность должны'},
#  {'type': 'text', 'content': 'соответствовать требованиям ГОСТ 18442-80.'},
#  {'type': 'text',
#   'content': '4.5. Повторный контроль люминесцентным или цветным методом, контроль полноты'},
#  {'type': 'text',
#   'content': 'удаления выявленных дефектов после выборки, контроль при замене одного метода другим'},
#  {'type': 'text',
#   'content': 'следует проводить в соответствии с пи. 4.1 - 4.4.'},
#  {'type': 'text', 'content': '4.6. Классификация индикаторных следов.'},
#  {'type': 'text',
#   'content': '4.6.1. Индикаторные следы при контроле капиллярными методами при наличии дефек-'},
#  {'type': 'text',
#   'content': 'тов на контролируемой поверхности подразделяются на две группы: протяженные и округ-'},
#  {'type': 'text', 'content': 'лые.'},
#  {'type': 'text',
#   'content': '4.6.2. Протяженный индикаторный след характеризуется отношением длины к ширине'},
#  {'type': 'text', 'content': 'больше трех.'},
#  {'type': 'text',
#   'content': 'Трещины, закаты, подрезы, резкие западания наплавленного металла, заковы, близко'},
#  {'type': 'text',
#   'content': 'расположенные поры образуют протяженный индикаторный след.'},
#  {'type': 'text',
#   'content': '4.6.3. Округлый индикаторный след характеризуется отношением длины к ширине,'},
#  {'type': 'text', 'content': 'равным или меньшим трех.'},
#  {'type': 'text', 'content': '5. ТРЕБОВАНИЯ К ОФОРМЛЕНИЮ ДОКУМЕНТАЦИИ'},
#  {'type': 'text',
#   'content': '5.1. Результаты контроля фиксируются в журнале с обязательным заполнением всех его'},
#  {'type': 'text', 'content': 'граф.'},
#  {'type': 'text',
#   'content': 'Журнал должен иметь сквозную нумерацию страниц, быть прошнурован и скреплен'},
#  {'type': 'text',
#   'content': 'подписью руководителя службы неразрушающего контроля. Исправления должны быть под-'},
#  {'type': 'text',
#   'content': 'тверждены подписью руководителя службы неразрушающего контроля.'},
#  {'type': 'text',
#   'content': 'Журнал должен храниться на предприятии в архиве службы неразрушающего контроля'},
#  {'type': 'text', 'content': 'не менее 5 лет.'},
#  {'type': 'text',
#   'content': '5.2. На основании записей в журнале результатов контроля составляется заключение.'},
#  {'type': 'text',
#   'content': '5.3. Рекомендуемая форма журнала и заключения (с обязательным их содержанием)'},
#  {'type': 'text', 'content': 'приведены в приложении 7 (рекомендуемом).'},
#  {'type': 'text',
#   'content': 'Журнал и заключение могут быть дополнены и другими предусмотренными принятой'},
#  {'type': 'text', 'content': 'на предприятии системой сведениями.'},
#  {'type': 'text', 'content': '6. ТРЕБОВАНИЯ БЕЗОПАСНОСТИ'},
#  {'type': 'text',
#   'content': '6.1. К выполнению работ по капиллярному контролю допускаются лица (дефектоско-'},
#  {'type': 'text',
#   'content': 'писты), прошедшие специальный инструктаж по правилам безопасности, электробезопасно-'},
#  {'type': 'text',
#   'content': 'сти и противопожарной безопасности по действующим на данном предприятии инструкци-'},
#  {'type': 'text',
#   'content': 'ям, с записью о проведении инструктажа в специальном журнале. Требования к контролерам'},
#  {'type': 'text', 'content': 'изложены в приложении 8 (обязательном).'},
#  {'type': 'text',
#   'content': '6.2. При проведении работ по капиллярному контролю трубопроводов и оборудования'},
#  {'type': 'text',
#   'content': 'атомных электростанций следует руководствоваться Правилами технической эксплуатации'},
#  {'type': 'text',
#   'content': 'электроустановок потребителей и Правилами технической безопасности при эксплуатации'},
#  {'type': 'text',
#   'content': 'электроустановок потребителей, утвержденными Госэнергонадзором в 1969 г. с дополне-'},
#  {'type': 'text',
#   'content': 'ниями и изменениями 1971 г., Типовыми правилами пожарной безопасности для промыш-'},
#  {'type': 'text',
#   'content': 'ленных предприятий, утвержденными ГУ ПО МВД СССР в 1975 г.'},
#  {'type': 'text',
#   'content': '6.3. Контроль выполняется на специально оборудованном участке. Требования к участ-'},
#  {'type': 'text',
#   'content': 'ку капиллярного контроля приведены в рекомендуемом приложении 9.'},
#  {'type': 'text',
#   'content': '6.4. Перед каждым включением дефектоскопической аппаратуры необходимо убедить-'},
#  {'type': 'text',
#   'content': 'ся в надежном ее заземлении (если это предусмотрено инструкцией по эксплуатации).'},
#  {'type': 'text',
#   'content': '6.5. При работе в монтажных условиях подключение аппаратуры к сети электропитания'},
#  {'type': 'text',
#   'content': 'и отключение ее по окончании работы должны проводиться дежурным электромонтером.'},
#  {'type': 'text',
#   'content': '6.6. В случае недопустимости по правилам электробезопасности использования пи-'},
#  {'type': 'text',
#   'content': 'тающего напряжения 220 В следует применять аппаратуру на 36 В.'},
#  {'type': 'text',
#   'content': '6.7. Осмотр контролируемой поверхности с применением источника ультрафиолетово-'},
#  {'type': 'text',
#   'content': 'го излучения выполняют в соответствии с требованиями ГОСТ 18442-80.'},
#  {'type': 'text',
#   'content': '6.8. Запрещается проводить работы при выключенной вентиляции.'},
#  {'type': 'text',
#   'content': '6.9. На месте проведения работ должны быть вывешены плакаты "Огнеопасно", "С ог-'},
#  {'type': 'text', 'content': 'нем не входить".'},
#  {'type': 'text',
#   'content': 'На месте проведения работ не допускаются курение и наличие открытого огня.'},
#  {'type': 'text',
#   'content': '6.10. Наличие дефектоскопических материалов на рабочем месте разрешается только в'},
#  {'type': 'text',
#   'content': 'количестве, необходимом для выполнения сменного задания. Правила их хранения изложе-'},
#  {'type': 'text', 'content': 'ны в приложении 2 (обязательном).'},
#  {'type': 'text',
#   'content': '6.11. Дефектоскопические материалы должны быть расфасованы в полиэтиленовую'},
#  {'type': 'text',
#   'content': 'или нержавеющую металлическую посуду с завинчивающимися крышками или пробками в'},
#  {'type': 'text',
#   'content': 'соответствии с распространяющимися на них стандартами или техническими условиями.'},
#  {'type': 'text',
#   'content': '6.12. Все горючие вещества необходимо хранить в специальных металлических шкафах'},
#  {'type': 'text', 'content': 'или ящиках.'},
#  {'type': 'text',
#   'content': '6.13. Использованную обтирочную ткань необходимо хранить в металлической таре с'},
#  {'type': 'text', 'content': 'плотно закрывающейся крышкой.'},
#  {'type': 'text',
#   'content': '6.14. Контроль внутренней поверхности конструкций следует проводить при постоян-'},
#  {'type': 'text',
#   'content': 'ной подаче свежего воздуха внутрь контролируемого изделия во избежание скопления паров'},
#  {'type': 'text', 'content': 'растворителя.'},
#  {'type': 'text',
#   'content': '6.15. Все работы по контролю необходимо проводить в спецодежде (халат, медицин-'},
#  {'type': 'text',
#   'content': 'ские резиновые перчатки, головной убор; куртка ватная - при контроле в зимних условиях).'},
#  {'type': 'text',
#   'content': 'При пользовании резиновыми перчатками руки необходимо предварительно покрыть таль-'},
#  {'type': 'text', 'content': 'ком или смазать вазелином.'},
#  {'type': 'text',
#   'content': '6.16. При работе с дефектоскопическими материалами в аэрозольной упаковке необхо-'},
#  {'type': 'text',
#   'content': 'димо соблюдать следующие меры предосторожности: не проводить распыление вблизи от-'},
#  {'type': 'text',
#   'content': 'крытого огня, не допускать нагревание баллона выше 50°С, не курить; при распылении не'},
#  {'type': 'text',
#   'content': 'допускать попадания состава в глаза; не следует открывать, разрушать или выбрасывать бал-'},
#  {'type': 'text', 'content': 'лон до полного его использования.'},
#  {'type': 'text',
#   'content': '6.17. Руки после окончания работ следует немедленно вымыть теплой водой с мылом.'},
#  {'type': 'text',
#   'content': 'Применение для мытья рук керосина, бензина и других органических растворителей запре-'},
#  {'type': 'text', 'content': 'щается.'},
#  {'type': 'text',
#   'content': 'При сухости рук после работы необходимо применять ланолиновый или витаминизи-'},
#  {'type': 'text', 'content': 'рованный крем.'},
#  {'type': 'text',
#   'content': '6.18. Для снижения утомляемости контролеров и повышения качества контроля целе-'},
#  {'type': 'text',
#   'content': 'сообразно через каждый час расшифровки следов дефектов делать перерыв 10 - 15 мин.'},
#  {'type': 'text',
#   'content': '9. При проведении капиллярного контроля следует использовать реактивы и материа-'},
#  {'type': 'text', 'content': 'лы, указанные в справочном приложении 10.'},
#  {'type': 'text', 'content': 'ПРИЛОЖЕНИЕ 1'},
#  {'type': 'text', 'content': '(обязательное)'},
#  {'type': 'text',
#   'content': 'ПРИГОТОВЛЕНИЕ ИНДИКАТОРНЫХ ПЕНЕТРАНТОВ, ПРОЯВИТЕЛЕЙ,'},
#  {'type': 'text', 'content': 'ОЧИСТИТЕЛЕЙ'},
#  {'type': 'text', 'content': '1. Приготовление индикаторных пенетрантов.'},
#  {'type': 'text', 'content': '1.1. Индикаторный пенетрант Wj):'},
#  {'type': 'text',
#   'content': 'нориол А (150 мл) подогревают на водяной бане при температуре 60°C, добавляют ке-'},
#  {'type': 'text',
#   'content': 'росин (850 мл) и перемешивают в течение 30 мин.'},
#  {'type': 'text', 'content': '1.2. Индикаторный пенетрант И162:'},
#  {'type': 'text',
#   'content': 'нориол А (50 мл) добавляют в бензин (950 мл) и тщательно перемешивают до полного'},
#  {'type': 'text', 'content': 'растворения.'},
#  {'type': 'text', 'content': '1.3. Индикаторный пенетрант 9):'},
#  {'type': 'text',
#   'content': 'красная проникающая жидкость "К", поставляемая заводом-изготовителем.'},
#  {'type': 'text', 'content': '1.4. Индикаторный пенетрант W292:'},
#  {'type': 'text',
#   'content': 'краситель жирорастворимый темно-красный "Ж" (5 г) растворяют в скипидаре (500 мл)'},
#  {'type': 'text',
#   'content': 'на водяной бане при температуре 60°С в течение 30 мин; краситель жирорастворимый тем-'},
#  {'type': 'text',
#   'content': 'но-красный 5С (5 г) растворяют в смеси керосина (200 мл) и бензина (300 мл) на водяной ба-'},
#  {'type': 'text',
#   'content': 'не при температуре 60°C в течение 30 мин. Полученные растворы после охлаждения до тем-'},
#  {'type': 'text', 'content': 'пературы окружающего воздуха сливают вместе.'},
#  {'type': 'text', 'content': '1.5. Индикаторный пенетрант W493:'},
#  {'type': 'text',
#   'content': 'краситель жирорастворимый темно-красный "Ж" (5 г) растворяют в скипидаре (500 мл)'},
#  {'type': 'text',
#   'content': 'на водяной бане при температуре 60°С в течение 30 мин; краситель жирорастворимый тем-'},
#  {'type': 'text',
#   'content': 'но-красный 5С (5 г) растворяют в смеси бензина (470 мл) с ксилолом (30 мл) на водяной бане'},
#  {'type': 'text',
#   'content': 'при температуре 60°C в течение 30 мин. Полученные растворы после охлаждения до темпе-'},
#  {'type': 'text', 'content': 'ратуры окружающего воздуха сливают вместе.'},
#  {'type': 'text', 'content': '1.6. Индикаторный пенетрант W494:'},
#  {'type': 'text',
#   'content': 'краситель жирорастворимый темно-красный "Ж" (10 г) растворяют в смеси скипидара'},
#  {'type': 'text',
#   'content': '(600 мл) и нориола А (100 мл) на водяной бане при температуре 60°C в течение 30 мин; к по-'},
#  {'type': 'text', 'content': 'лученному раствору добавляют бензин (300 мл).'},
#  {'type': 'text',
#   'content': '1.7. Индикаторный пенетрант И›05 поставляется в готовом виде в составе набора дефек-'},
#  {'type': 'text', 'content': 'тоскопических материалов ИФХ-КОЛОР-4.'},
#  {'type': 'text',
#   'content': '1.8. Индикаторный пенетрант M96 поставляется в готовом виде в составе набора дефек-'},
#  {'type': 'text', 'content': 'тоскопических материалов ДАК-2Ц.'},
#  {'type': 'text',
#   'content': '1.9. Индикаторный пенетрант И›07 поставляется в готовом виде в составе набора дефек-'},
#  {'type': 'text', 'content': 'тоскопических материалов ДАК-ЗЦ.'},
#  {'type': 'text',
#   'content': '1.10. Цветные индикаторные пенетранты необходимо отфильтровать (через фильтро-'},
#  {'type': 'text',
#   'content': 'вальную бумагу, вату или сложенную в два слоя бязь) сразу же после охлаждения приготов-'},
#  {'type': 'text', 'content': 'ленного раствора до комнатной температуры.'},
#  {'type': 'text', 'content': '2. Приготовление проявителей.'},
#  {'type': 'text', 'content': '2.1. Проявитель [Ш101:'},
#  {'type': 'text',
#   'content': 'в каолин (250 г) добавляют спирт (1000 мл) и перемешивают до однородной массы.'},
#  {'type': 'text', 'content': '2.2. Проявитель [1102:'},
#  {'type': 'text',
#   'content': 'белая проявляющая краска "М", поставляемая заводом-изготовителем.'},
#  {'type': 'text', 'content': '2.3. Проявитель [1103:'},
#  {'type': 'text',
#   'content': 'в каолин (200 г) добавляют натрия карбонат безводный (кальцинированную соду) в ко-'},
#  {'type': 'text',
#   'content': 'личестве 20 ги спирт (1000 мл), перемешивают до однородной массы.'},
#  {'type': 'text', 'content': '2.4. Проявитель [1501:'},
#  {'type': 'text',
#   'content': 'поставляется в готовом виде в составе набора дефектоскопических материалов ИФХ-'},
#  {'type': 'text', 'content': 'КОЛОР-4.'},
#  {'type': 'text', 'content': '2.5. Проявитель [1]502:'},
#  {'type': 'text',
#   'content': 'поставляется в готовом виде в составе набора ДАК-2Ц.'},
#  {'type': 'text', 'content': '2.6. Проявитель [1503:'},
#  {'type': 'text',
#   'content': 'поставляется в готовом виде в составе набора ДАК-ЗЦ.'},
#  {'type': 'text', 'content': '3. Приготовление очистителей.'},
#  {'type': 'text', 'content': '3.1. Очиститель M0):'},
#  {'type': 'text',
#   'content': 'порошкообразное синтетическое моющее средство любой марки (5 г) растворяют в во-'},
#  {'type': 'text', 'content': 'де (1000 мл).'},
#  {'type': 'text', 'content': '3.2. Очиститель М1о2:'},
#  {'type': 'text',
#   'content': 'смесь трансформаторного масла (700 мл) и керосина (300 мл).'},
#  {'type': 'text', 'content': '3.3. Очиститель M0):'},
#  {'type': 'text', 'content': 'спирт этиловый.'},
#  {'type': 'text', 'content': '3.4. Очиститель M493:'},
#  {'type': 'text',
#   'content': 'сливают скипидар (500 мл), бензин (300 мл), керосин (200 мл) и перемешивают.'},
#  {'type': 'text', 'content': '3.5. Очиститель M493:'},
#  {'type': 'text', 'content': '3.6. Очиститель Мол:'},
#  {'type': 'text',
#   'content': 'поставляется в готовом виде в составе набора ДАК-2Ц.'},
#  {'type': 'text', 'content': '3.7. Очиститель My 5:'},
#  {'type': 'text',
#   'content': 'поставляется в готовом виде в составе набора ДАК-ЗЦ.'},
#  {'type': 'text',
#   'content': '4. При проведении капиллярного контроля приведенные в документе наборы дефекто-'},
#  {'type': 'text',
#   'content': 'скопических материалов могут быть использованы в аэрозольной упаковке.'},
#  {'type': 'text', 'content': 'ПРИЛОЖЕНИЕ 2'},
#  {'type': 'text', 'content': '(обязательное)'},
#  {'type': 'text',
#   'content': 'ПРАВИЛА ХРАНЕНИЯ И ПРОВЕРКА КАЧЕСТВА ДЕФЕКТОСКОПИЧЕСКИХ'},
#  {'type': 'text', 'content': 'МАТЕРИАЛОВ'},
#  {'type': 'text',
#   'content': '1. Дефектоскопические материалы при входном контроле проверяются по сопроводи-'},
#  {'type': 'text',
#   'content': 'тельной документации (этикетки, упаковочные листы) на соответствие ГОСТу и техниче-'},
#  {'type': 'text',
#   'content': 'ским условиям, указанным в справочном приложении 10.'},
#  {'type': 'text',
#   'content': '2. Дефектоскопические материалы хранятся в соответствии с требованиями распро-'},
#  {'type': 'text',
#   'content': 'страняющихся на них стандартов или технических условий.'},
#  {'type': 'text',
#   'content': '3. Наборы дефектоскопических материалов хранятся в соответствии с требованиями'},
#  {'type': 'text',
#   'content': 'документации на материалы, из которых они составлены.'},
#  {'type': 'text',
#   'content': '4. Дефектоскопические материалы (индикаторные пенетранты и проявители) следует'},
#  {'type': 'text',
#   'content': 'хранить в герметичной посуде. Индикаторные пенетранты необходимо хранить в светоне-'},
#  {'type': 'text',
#   'content': 'проницаемой посуде или в защищенном от света месте.'},
#  {'type': 'text',
#   'content': '5. Пригодность дефектоскопических материалов следует проверять на контрольных 00-'},
#  {'type': 'text',
#   'content': 'разцах (см. рекомендуемые приложения 3 и 4) после приготовления набора дефектоскопиче-'},
#  {'type': 'text',
#   'content': 'ских материалов, а затем не реже одного раза в неделю.'},
#  {'type': 'text',
#   'content': '6. Очистку контрольных образцов следует проводить выдержкой в ацетоне не менее 5 -'},
#  {'type': 'text',
#   'content': '6 ч или промывкой в ацетоне при воздействии ультразвуком в режиме кавитации в течение'},
#  {'type': 'text',
#   'content': '60 мин, после чего образцы должны быть высушены и прогреты при максимальной темпера-'},
#  {'type': 'text',
#   'content': 'Type, не вызывающей окисления металла, в течение 15 мин.'},
#  {'type': 'text',
#   'content': '7. Контрольные образцы должны быть аттестованы и подвергаться периодической про-'},
#  {'type': 'text', 'content': 'верке.'},
#  {'type': 'text',
#   'content': '8. Применение контрольных образцов, изготовленных другими способами, а также им-'},
#  {'type': 'text',
#   'content': 'портных, следует согласовать с головной отраслевой материаловедческой организацией.'},
#  {'type': 'text',
#   'content': '9. Контрольные образцы должны иметь дефекты типа неразветвленных тупиковых'},
#  {'type': 'text',
#   'content': 'трещин с раскрытиями, соответствующими применяемым классам чувствительности.'},
#  {'type': 'text',
#   'content': '10. Контрольные образцы могут быть изготовлены из любых металлических коррози-'},
#  {'type': 'text',
#   'content': 'онно-стойких материалов способами, принятыми на предприятии-изготовителе.'},
#  {'type': 'text',
#   'content': 'К образцам должен быть приложен паспорт с фотографией картины выявленных де-'},
#  {'type': 'text',
#   'content': 'фектов и указанием набора дефектоскопических материалов, с помощью которых проводил-'},
#  {'type': 'text',
#   'content': 'ся контроль. Форма паспорта на контрольный образец является рекомендуемой, а содержа-'},
#  {'type': 'text',
#   'content': 'ние паспорта - обязательным. Паспорт оформляется службой неразрушающих методов кон-'},
#  {'type': 'text', 'content': 'троля и метрологической службой предприятия.'},
#  {'type': 'text',
#   'content': 'Периодичность поверки контрольных образцов устанавливается в соответствии с при-'},
#  {'type': 'text', 'content': 'ложением 4 (рекомендуемым).'},
#  {'type': 'text',
#   'content': '11. Если контрольный образец после очистки не соответствует паспортным данным,'},
#  {'type': 'text', 'content': 'его следует заменить новым.'},
#  {'type': 'text', 'content': 'ПРИЛОЖЕНИЕ 3'},
#  {'type': 'text', 'content': '(рекомендуемое)'},
#  {'type': 'text',
#   'content': 'ТЕХНОЛОГИЯ ИЗГОТОВЛЕНИЯ КОНТРОЛЬНЫХ ОБРАЗЦОВ ДЛЯ ИСПЫ-'},
#  {'type': 'text', 'content': 'ТАНИЯ ДЕФЕКТОСКОПИЧЕСКИХ НАБОРОВ'},
#  {'type': 'text', 'content': 'Образец № 1'},
#  {'type': 'text',
#   'content': '1. Образец представляет собой объект контроля из коррозионно-стойкого материала'},
#  {'type': 'text', 'content': '(или его часть) с естественными дефектами.'},
#  {'type': 'text',
#   'content': '2. Ширину трещины измеряют на металлографическом микроскопе. Для / класса чувст-'},
#  {'type': 'text',
#   'content': 'вительности точность измерения ширины раскрытия - до 0,3 мкм, для П и Ш классов - до |'},
#  {'type': 'text', 'content': 'МКМ.'},
#  {'type': 'text', 'content': 'Образец № 2'},
#  {'type': 'text',
#   'content': '1. Образец изготовляют из листовой стали марки 40X13 по ГОСТ 5949-75 размером'},
#  {'type': 'text', 'content': '100x30x(3-4) мм.'},
#  {'type': 'text',
#   'content': '2. Вдоль образца проплавляют шов аргонодуговой сваркой без применения присадоч-'},
#  {'type': 'text', 'content': 'ной проволоки в режиме /=100 А, Ц =10-15 В.'},
#  {'type': 'text',
#   'content': '3. Образец изгибают на любом приспособлении до появления трещин.'},
#  {'type': 'text',
#   'content': '4. Ширину трещин измеряют на микроскопе (см. выше).'},
#  {'type': 'text', 'content': 'Образец № 3'},
#  {'type': 'text',
#   'content': '1. Образец изготовляют из листовой стали ЭИ-962 (1X12H2BM®) по техническим ус-'},
#  {'type': 'text',
#   'content': 'ловиям размером 30x70x3 мм. Допускается применение любой азотируемой стали.'},
#  {'type': 'text',
#   'content': '2. Полученную заготовку рихтуют и шлифуют на глубину 0,1 мм с одной рабочей сто-'},
#  {'type': 'text', 'content': 'роны.'},
#  {'type': 'text',
#   'content': '3. Заготовку азотируют на глубину 0,3 мм без последующей закалки.'},
#  {'type': 'text',
#   'content': '4. Рабочую сторону шлифуют на глубину 0,02-0,05 мм. Параметр шероховатости по-'},
#  {'type': 'text', 'content': 'верхности R, 40 мкм по ГОСТ 2789-73.'},
#  {'type': 'text',
#   'content': '5. Образец помещают в приспособление (ГОСТ 23349-84), приспособление устанавли-'},
#  {'type': 'text',
#   'content': 'вают в тиски и плавно зажимают до появления характерного хруста азотированного слоя.'},
#  {'type': 'text',
#   'content': '6. Ширину трещин измеряют на микроскопе (см. выше).'},
#  {'type': 'table', 'content': [['']]},
#  {'type': 'table', 'content': [['']]},
#  {'type': 'table',
#   'content': [['Номер трещины от клейма', 'Размеры', '‘трещин', 'Примечание'],
#    ['и', 'ширина раскрытия, мкм', 'длина, мм', 'и'],
#    ['и', 'п', 'PT', 'pe']]},
#  {'type': 'table', 'content': [['']]},
#  {'type': 'table', 'content': [['']]},
#  {'type': 'text', 'content': 'ПРИЛОЖЕНИЕ 4'},
#  {'type': 'text', 'content': '(рекомендуемое)'},
#  {'type': 'text', 'content': 'ПАСПОРТ'},
#  {'type': 'text', 'content': 'НА КОНТРОЛЬНЫЙ ОБРАЗЕЦ №'},
#  {'type': 'text',
#   'content': 'Контрольный образец из стали марки предназначен для оценки чувст-'},
#  {'type': 'text', 'content': 'вительности применяемого метода контроля.'},
#  {'type': 'text', 'content': 'На образце имеется поверхностных трещин.'},
#  {'type': 'text',
#   'content': 'Нумерация трещин начинается от клейма. Размеры трещин представлены в таблице.'},
#  {'type': 'text', 'content': 'Номер трещины от'},
#  {'type': 'text', 'content': 'клейма'},
#  {'type': 'text', 'content': 'Размеры трещин Примечание'},
#  {'type': 'text', 'content': 'ширина раскрытия,'},
#  {'type': 'text', 'content': 'мкм'},
#  {'type': 'text', 'content': 'И ПИ ОИ ОО'},
#  {'type': 'text',
#   'content': 'Контрольный образец аттестован __ (дата) и признан годным для определения чувстви-'},
#  {'type': 'text',
#   'content': 'тельности капиллярного контроля по классу при проведении контроля набором дефек-'},
#  {'type': 'text', 'content': 'тоскопических материалов по'},
#  {'type': 'text', 'content': 'длина, мм'},
#  {'type': 'text', 'content': 'Фотография контрольного образца прилагается.'},
#  {'type': 'text',
#   'content': 'В графе "Примечание" указывается срок очередной аттестации в зависимости от усло-'},
#  {'type': 'text', 'content': 'вий производства, но не реже 1 раза в год.'},
#  {'type': 'text', 'content': 'ПРИЛОЖЕНИЕ 5'},
#  {'type': 'text', 'content': '(обязательное)'},
#  {'type': 'text', 'content': 'КОНТРОЛЬНЫЙ ОБРАЗЕЦ ФОНА'},
#  {'type': 'text',
#   'content': 'На металлическую поверхность наносят проявитель П1о1 или П1оз и высушивают.'},
#  {'type': 'text',
#   'content': 'Ha высохший слой проявителя однократно наносят индикаторный пенетрант И›д›, раз-'},
#  {'type': 'text',
#   'content': 'бавленный очистителем Мод» в 10 раз, и высушивают.'},
#  {'type': 'text', 'content': 'ПРИЛОЖЕНИЕ 6'},
#  {'type': 'text', 'content': '(рекомендуемое)'},
#  {'type': 'text',
#   'content': 'ПРИМЕНЕНИЕ ДЕФЕКТОСКОПИЧЕСКИХ МАТЕРИАЛОВ В АЭРОЗОЛЬНОЙ'},
#  {'type': 'text', 'content': 'УПАКОВКЕ'},
#  {'type': 'text',
#   'content': '1. При проведении капиллярного контроля допускается использование наборов дефек-'},
#  {'type': 'text',
#   'content': 'тоскопических материалов в аэрозольной упаковке.'},
#  {'type': 'text',
#   'content': '2. Баллон с проявителем перед употреблением необходимо встряхивать в течение 2 - 3'},
#  {'type': 'text', 'content': 'мин с целью перемешивания содержимого.'},
#  {'type': 'text',
#   'content': '3. При нанесении на поверхность дефектоскопических материалов с помощью аэро-'},
#  {'type': 'text',
#   'content': 'зольных баллонов головка баллона должна находиться на расстоянии 300 - 350 мм от кон-'},
#  {'type': 'text', 'content': 'тролируемого участка.'},
#  {'type': 'text',
#   'content': '4. Перед нанесением проявителя на контролируемую поверхность следует убедиться в'},
#  {'type': 'text',
#   'content': 'хорошем качестве распыления, нажав на распылительную головку и направив струю в сто-'},
#  {'type': 'text', 'content': 'рону от детали.'},
#  {'type': 'text',
#   'content': '5. Не допускается закрывать клапан при направлении струи на деталь во избежание по-'},
#  {'type': 'text',
#   'content': 'падания крупных капель проявителя на контролируемую поверхность.'},
#  {'type': 'text',
#   'content': '6. В случае засорения распылительной головки последнюю необходимо извлечь из'},
#  {'type': 'text',
#   'content': 'гнезда, промыть в ацетоне и продуть сжатым воздухом (резиновой грушей).'},
#  {'type': 'table',
#   'content': [['7',
#     '||',
#     'о | ae о',
#     'SoS cm',
#     '|',
#     '|',
#     'Выя',
#     'вленные',
#     'дефекты',
#     '2 3 i',
#     ''],
#    ['к B а. ss Е =) ie к Ss Е oO Fl o а о a, Е fae) Ss io) FC',
#     'к ы Е oO Ft ag) = o Ss Fa fo) а © Е o = = i) a.',
#     'ыы с 3 a о 3 mM vw Е = с = = оч em a, < Е = & 3 о = o Е & 2 o = он в oO 3',
#     'ct Zz 2 о > as "5 53 а: 2 2. 8 . ЕЕ = в ~ 3 Е ь ан = 3 S25 2 oO ко == ЕЕ Бо ={re',
#     'к B а. ss Е =) У = o r = ©',
#     'р 3 = rs Xe) eq 3 ee) = о oO > x я 3 i en) oO =| O',
#     'o Е а. ss Е © = = © Е 5” ы а a, o Е = oF Е',
#     'о = о - о faa) о. cD) = cD) = о 5 = cD) = о Я к = 5 2 Са SS a & Fe',
#     'о = о se о. о м a о Е cD) = о fo) Е oO 5 8 os e = oO ok 8 = a5 Fs',
#     'ge) al QO 5 ea 2) cD) с © Е = 3 BR A Soe = а о № ~*~ xs eo 5 в я ЯЗ к Е 5 A, = = 5 = © me',
#     'я | я Е > a) = = = fae} © С ='],
#    ['||', '|', 'о', 'По', '|', 'ПИ', '|', 'P|', 'po', 'о', 'Пи']]},
#  {'type': 'table', 'content': [['']]},
#  {'type': 'table', 'content': [['']]},
#  {'type': 'table', 'content': [['']]},
#  {'type': 'table', 'content': [['']]},
#  {'type': 'table', 'content': [['']]},
#  {'type': 'table', 'content': [['']]},
#  {'type': 'text', 'content': 'ПРИЛОЖЕНИЕ 7'},
#  {'type': 'text', 'content': '(рекомендуемое)'},
#  {'type': 'text', 'content': 'ФОРМА ЖУРНАЛА'},
#  {'type': 'text', 'content': 'Выявленные дефекты Оператор'},
#  {'type': 'text', 'content': 'Метод контроля (набор дефектоскопи-'},
#  {'type': 'text', 'content': 'ческих материалов, класс чувстви-'},
#  {'type': 'text', 'content': 'после повторного'},
#  {'type': 'text', 'content': 'тельности'},
#  {'type': 'text', 'content': 'Номер заключения по результатам'},
#  {'type': 'text', 'content': 'контроля и дата выдачи'},
#  {'type': 'text', 'content': 'о'},
#  {'type': 'text', 'content': 'Е'},
#  {'type': 'text', 'content': '©'},
#  {'type': 'text', 'content': 'a.'},
#  {'type': 'text', 'content': '3'},
#  {'type': 'text', 'content': 'a'},
#  {'type': 'text', 'content': 'о'},
#  {'type': 'text', 'content': '3'},
#  {'type': 'text', 'content': 'Е:'},
#  {'type': 'text', 'content': '='},
#  {'type': 'text', 'content': 'ne'},
#  {'type': 'text', 'content': 'oO'},
#  {'type': 'text', 'content': '='},
#  {'type': 'text', 'content': 'a,'},
#  {'type': 'text', 'content': 'oO'},
#  {'type': 'text', 'content': 'р'},
#  {'type': 'text', 'content': 'oO'},
#  {'type': 'text', 'content': 'S'},
#  {'type': 'text', 'content': '='},
#  {'type': 'text', 'content': 'oO'},
#  {'type': 'text', 'content': 'ey'},
#  {'type': 'text', 'content': '<'},
#  {'type': 'text', 'content': 'ra'},
#  {'type': 'text', 'content': 'ia)'},
#  {'type': 'text', 'content': 'о'},
#  {'type': 'text', 'content': '6'},
#  {'type': 'text', 'content': 'о'},
#  {'type': 'text', 'content': 'Дата проведения контроля'},
#  {'type': 'text', 'content': 'Наименование изделия'},
#  {'type': 'text', 'content': 'соединения, наплавки и т.п.'},
#  {'type': 'text', 'content': 'Объем контроля'},
#  {'type': 'text', 'content': 'Оценка качества в баллах'},
#  {'type': 'text', 'content': 'При первичном контроле'},
#  {'type': 'text', 'content': 'При контроле после первого ис-'},
#  {'type': 'text', 'content': 'правления'},
#  {'type': 'text', 'content': 'При контроле'},
#  {'type': 'text', 'content': 'исправления'},
#  {'type': 'text', 'content': 'Фамилия'},
#  {'type': 'text', 'content': 'Примечания:'},
#  {'type': 'text',
#   'content': '1. Техническую документацию по результатам капиллярного контроля необходимо хранить в архиве'},
#  {'type': 'text',
#   'content': 'предприятия-изготовителя в установленном порядке.'},
#  {'type': 'text',
#   'content': '2. В графе "Выявленные дефекты" следует приводить наибольшие размеры индикаторных следов.'},
#  {'type': 'text',
#   'content': '3. При необходимости следует делать эскизы расположения индикаторных следов.'},
#  {'type': 'text',
#   'content': '4. Оценка качества сварных соединений осуществляется по двухбалльной системе: балл 1 - неудовлетво-'},
#  {'type': 'text',
#   'content': 'рительное качество; балл 2 - удовлетворительное качество.'},
#  {'type': 'text',
#   'content': 'Выбор балла оценки определяется требованиями норм, установленных ПНАЭ Г-7-010-89.'},
#  {'type': 'text',
#   'content': 'ФОРМА ЗАКЛЮЧЕНИЯ ПО КОНТРОЛЮ КАЧЕСТВА СВАРНЫХ СОЕДИНЕ-'},
#  {'type': 'text', 'content': 'НИЙ И НАПЛАВКИ МЕТОДАМИ КАПИЛЛЯРНОГО КОНТРОЛЯ'},
#  {'type': 'text', 'content': 'ЗАКЛЮЧЕНИЕ Ne |'},
#  {'type': 'text',
#   'content': 'по капиллярному контролю качества сварных соединений'},
#  {'type': 'text', 'content': 'методом'},
#  {'type': 'text', 'content': 'цветным, люминесцентным'},
#  {'type': 'text', 'content': 'дата, город, поселок'},
#  {'type': 'text', 'content': 'Проверка качества поверхности'},
#  {'type': 'text', 'content': 'внутренней, наружной'},
#  {'type': 'text', 'content': 'сварных соединений'},
#  {'type': 'text', 'content': 'наименование узла, номер чертежа, системы'},
#  {'type': 'text', 'content': 'проводилась согласно'},
#  {'type': 'text', 'content': 'наименование документа'},
#  {'type': 'text', 'content': 'с оценкой качества по'},
#  {'type': 'text', 'content': 'наименование документа'},
#  {'type': 'table', 'content': [['']]},
#  {'type': 'table', 'content': [['']]},
#  {'type': 'table',
#   'content': [['Номер свар- ного соеди- нения по чер- тежу',
#     'Объем контроля, %',
#     'Номер записи в журнале резуль- татов контроля',
#     'Описание об- наруженных дефектов',
#     'Оценка качества в баллах',
#     'Примечание'],
#    ['', 'по', 'Пи', 'по', 'пои', 'Po']]},
#  {'type': 'table', 'content': [['']]},
#  {'type': 'table', 'content': [['']]},
#  {'type': 'table', 'content': [['']]},
#  {'type': 'text', 'content': 'для категории'},
#  {'type': 'text', 'content': 'Сварочный формуляр (чертеж) №'},
#  {'type': 'text', 'content': 'РЕЗУЛЬТАТЫ КОНТРОЛЯ'},
#  {'type': 'text', 'content': 'Номер свар-'},
#  {'type': 'text', 'content': 'ного соеди-'},
#  {'type': 'text', 'content': 'нения по чер-'},
#  {'type': 'text', 'content': 'Объем Номер записи в Описание об- Оценка'},
#  {'type': 'text',
#   'content': 'контроля, | журнале резуль- наруженных качествав | Примечание'},
#  {'type': 'text', 'content': 'татов контроля дефектов'},
#  {'type': 'text',
#   'content': 'Подпись руководителя подразделения неразрушающих'},
#  {'type': 'text', 'content': 'методов контроля'},
#  {'type': 'text', 'content': '" " 19 Г'},
#  {'type': 'text',
#   'content': 'Примечание. Форма заключения справедлива также для контроля основных материалов (полу-'},
#  {'type': 'text', 'content': 'фабрикатов).'},
#  {'type': 'text', 'content': 'ПРИЛОЖЕНИЕ 8'},
#  {'type': 'text', 'content': '(обязательное)'},
#  {'type': 'text', 'content': 'АТТЕСТАЦИЯ КОНТРОЛЕРОВ'},
#  {'type': 'text',
#   'content': 'К проведению капиллярного контроля сварных соединений и наплавки оборудования и'},
#  {'type': 'text',
#   'content': 'трубопроводов АЭУ допускаются контролеры, аттестованные в соответствии с требования-'},
#  {'type': 'text',
#   'content': 'ми документа ПНАЭ Г-7-010-89; к проведению капиллярного контроля основного металла'},
#  {'type': 'text',
#   'content': '(полуфабрикатов) допускаются контролеры, аттестованные в порядке, аналогичном изло-'},
#  {'type': 'text', 'content': 'женному в ПНАЭ Г-7-010-89.'},
#  {'type': 'text',
#   'content': 'Для контролеров, осуществляющих контроль капиллярными методами, обязательно'},
#  {'type': 'text',
#   'content': 'обследование у окулиста с проверкой цветового зрения.'},
#  {'type': 'text', 'content': 'ПРИЛОЖЕНИЕ 9'},
#  {'type': 'text', 'content': '(рекомендуемое)'},
#  {'type': 'text',
#   'content': 'ОРГАНИЗАЦИЯ УЧАСТКА ДЛЯ ПРОВЕДЕНИЯ КАПИЛЛЯРНОГО'},
#  {'type': 'text', 'content': 'КОНТРОЛЯ'},
#  {'type': 'text',
#   'content': '1. Участок для проведения капиллярного контроля должен иметь изолированное поме-'},
#  {'type': 'text', 'content': '2'},
#  {'type': 'text', 'content': 'щение площадью не менее 20 м“.'},
#  {'type': 'text',
#   'content': '2. Участок должен быть размещен в сухом отапливаемом помещении с естественным и'},
#  {'type': 'text', 'content': 'искусственным освещением.'},
#  {'type': 'text',
#   'content': '3. Рабочие места для контроля должны быть оборудованы приточно-вытяжной венти-'},
#  {'type': 'text',
#   'content': 'ляцией и местными вытяжками не менее чем с трехкратным обменом воздуха.'},
#  {'type': 'text',
#   'content': '4. Кратность циркуляции воздуха должна быть рассчитана так, чтобы она соответство-'},
#  {'type': 'text',
#   'content': 'вала требованиям CH245-71; концентрация паров применяемых веществ в рабочей зоне'},
#  {'type': 'text',
#   'content': 'должна соответствовать требованиям ГОСТ 12.1.005-76.'},
#  {'type': 'text',
#   'content': '5. Стены и пол в помещении участка должны быть покрыты легко моющимися мате-'},
#  {'type': 'text', 'content': 'риалами (например, метлахская плитка).'},
#  {'type': 'text',
#   'content': '6. Участок для контроля должен быть оснащен холодной, горячей водой и сжатым воз-'},
#  {'type': 'text',
#   'content': 'духом. Сжатый воздух должен поступать на участок через влагомаслоотделитель.'},
#  {'type': 'text',
#   'content': '7. Участок для капиллярного контроля должен быть оборудован ванными и приспособ-'},
#  {'type': 'text',
#   'content': 'лениями для смыва индикаторного пенетранта с поверхности.'},
#  {'type': 'text',
#   'content': '8. Над рабочими местами должны быть установлены вытяжные зонты.'},
#  {'type': 'text',
#   'content': 'Примечание. В случае применения дефектоскопических материалов по другим стандартам и'},
#  {'type': 'text',
#   'content': 'техническим условиям это должно быть согласовано с головной отраслевой материаловедческой организацией'},
#  {'type': 'text', 'content': 'или авторами методики.'},
#  {'type': 'text',
#   'content': '9. На участке должны быть шкафы для хранения дефектоскопических материалов и'},
#  {'type': 'text', 'content': 'приспособлений.'},
#  {'type': 'text',
#   'content': '10. Для проведения контроля люминесцентным методом участок должен быть оснащен'},
#  {'type': 'text',
#   'content': 'люминесцентной аппаратурой. На участке должна быть предусмотрена возможность затем-'},
#  {'type': 'text', 'content': 'нения.'},
#  {'type': 'text',
#   'content': '11. Участок, на котором проводят капиллярный контроль крупногабаритных изделий,'},
#  {'type': 'text',
#   'content': 'должен быть оборудован (в дополнение к вышеперечисленному) грузоподъемными средст-'},
#  {'type': 'text',
#   'content': 'вами, а также поддонами для сбора воды и составов, используемых для контроля.'},
#  {'type': 'text',
#   'content': '12. Допускается проводить контроль капиллярными методами на производственных'},
#  {'type': 'text',
#   'content': 'участках (и монтажных) при условии полного соблюдения методики проведения контроля и'},
#  {'type': 'text', 'content': 'требований техники безопасности.'},
#  {'type': 'table',
#   'content': [['Материал (реактив)', 'Нормативный документ'],
#    ['', 'к НИ'],
#    ['Набор дефектоскопических материалов', 'В'],
#    ['ИФХ-КОЛОР-4 ДАК-2Ц ДАК-ЗЦ',
#     'ТУ88 УССР 206-39-87 ТУб-15-904-79 ТУ 6-16-1360-82']]},
#  {'type': 'text', 'content': 'ПРИЛОЖЕНИЕ 10'},
#  {'type': 'text', 'content': '(справочное)'},
#  {'type': 'text',
#   'content': 'ПЕРЕЧЕНЬ PEAKTHBOB И МАТЕРИАЛОВ, ПРИМЕНЯЕМЫХ ДЛЯ КАПИЛ-'},
#  {'type': 'text', 'content': 'ЛЯРНОГО КОНТРОЛЯ'},
#  {'type': 'text', 'content': 'Материал (реактив) Нормативный документ'},
#  {'type': 'text', 'content': '"Бензин Б-70 дия промышленно-технических |'},
#  {'type': 'text', 'content': '[Каолин, обогащенный для парфюмерной |'},
#  {'type': 'text', 'content': 'покер качества |'},
#  {'type': 'text', 'content': '"Марля медицинская | ГОСт941277 |'},
#  {'type': 'text', 'content': 'Набор дефектоскопических материалов'},
#  {'type': 'text', 'content': 'TY88 УССР 206-39-87'},
#  {'type': 'text', 'content': 'ДАК-2Ц TY6-15-904-79'},
#  {'type': 'text', 'content': 'ДАК-ЗЦ ТУ 6-16-1360-82'},
#  {'type': 'text', 'content': 'юминофор'},
#  {'type': 'text', 'content': 'раска'},
#  {'type': 'text',
#   'content': 'Жидкость "К" красная проникающая ТУ 6-10-750-79'},
#  {'type': 'text', 'content': 'ИФХ-КОЛОР-4'},
#  {'type': 'text',
#   'content': 'Примечание. В случае применения дефектоскопических материалов по другим стандартам и'},
#  {'type': 'text',
#   'content': 'техническим условиям это должно быть согласовано с головной отраслевой материаловедческой организацией'},
#  {'type': 'text', 'content': 'или авторами методики.'},
#  {'type': 'text', 'content': 'ПРИЛОЖЕНИЕ 11'},
#  {'type': 'text', 'content': '(справочное)'},
#  {'type': 'text',
#   'content': 'ОРИЕНТИРОВОЧНЫЙ РАСХОД ДЕФЕКТОСКОПИЧЕСКИХ МАТЕРИАЛОВ В'},
#  {'type': 'text', 'content': 'РАСЧЕТЕ НА 1 M* КОНТРОЛИРУЕМОЙ ПОВЕРХНОСТИ'},
#  {'type': 'text', 'content': 'Индикаторный пенетрант0,3 л'},
#  {'type': 'text', 'content': 'Очиститель1,2 л'},
#  {'type': 'text', 'content': 'Проявитель0,49'},
#  {'type': 'text', 'content': 'Бязь2,4 м”'},
#  {'type': 'text',
#   'content': 'ОРИЕНТИРОВОЧНЫЙ РАСХОД ДЕФЕКТОСКОПИЧЕСКИХ ПРИНАДЛЕЖ-'},
#  {'type': 'text',
#   'content': 'НОСТЕЙ В РАСЧЕТЕ НА 10 M’ КОНТРОЛИРУЕМОЙ ПОВЕРХНОСТИ'},
#  {'type': 'text', 'content': 'Перчатки резиновые хирургические3 пары'},
#  {'type': 'text', 'content': 'Перчатки хлопчатобумажные? пары'},
#  {'type': 'text', 'content': 'Кисти и щетки малярные2 пары'},
#  {'type': 'text', 'content': 'Кисти художественные № 20 - 242 пары'}]

# %%
import hashlib


# ============================================================
#           ВСПОМОГАТЕЛЬНЫЕ ФУНКЦИИ
# ============================================================

def tokenize_len(text: str) -> int:
    """Простейший токенайзер: считает слова."""
    return len(text.split())


def hash_text(text: str) -> str:
    """MD5-хэш текста — чтобы помечать таблицы."""
    return hashlib.md5(text.encode("utf-8")).hexdigest()


def convert_table_to_text(table):
    """
    Преобразует таблицу (list[list[str]]) в текст формата:
    | A | B | C |
    """
    lines = []
    for row in table:
        line = "| " + " | ".join(str(c) for c in row) + " |"
        lines.append(line)
    return "\n".join(lines)


# ============================================================
#      МЯГКОЕ ДЕЛЕНИЕ СЛИШКОМ БОЛЬШОГО ЛОГИЧЕСКОГО БЛОКА
# ============================================================

def split_block_soft(block, min_size, max_size):
    """Режет слишком большой логический блок по словам."""
    words = block.split()
    parts = []
    cur = []
    cur_len = 0

    for w in words:
        wl = tokenize_len(w)
        if cur_len + wl > max_size:
            parts.append(" ".join(cur))
            cur = [w]
            cur_len = wl
        else:
            cur.append(w)
            cur_len += wl

    if cur:
        parts.append(" ".join(cur))

    return parts


# ============================================================
#             ЛОГИЧЕСКОЕ ДЕЛЕНИЕ ТАБЛИЦЫ
# ============================================================

def split_table_logically(table_text, min_size, max_size):
    """
    Делит таблицу логически корректно:
    - строки с пустой первой ячейкой считаются продолжением предыдущей
    - блоки не рвутся
    - слишком большие блоки мягко режутся
    """

    lines = table_text.split("\n")

    blocks = []
    current_block = []

    def flush_block():
        nonlocal current_block
        if current_block:
            blocks.append("\n".join(current_block))
            current_block = []

    for line in lines:
        parts = [p.strip() for p in line.split("|")]

        first_cell = parts[1] if len(parts) > 1 else ""

        if not current_block:
            current_block.append(line)
            continue

        if first_cell == "":
            current_block.append(line)
        else:
            flush_block()
            current_block.append(line)

    flush_block()

    # собираем чанки
    result = []
    cur = []
    cur_len = 0

    def flush_chunk():
        nonlocal cur, cur_len
        if cur:
            result.append("\n".join(cur))
            cur = []
            cur_len = 0

    for block in blocks:
        bsize = tokenize_len(block)

        # если блок огромный — мягко режем
        if bsize > max_size:
            for small in split_block_soft(block, min_size, max_size):
                ssize = tokenize_len(small)
                if cur_len + ssize > max_size:
                    flush_chunk()
                cur.append(small)
                cur_len += ssize
            continue

        # обычный случай
        if cur_len + bsize > max_size:
            flush_chunk()

        cur.append(block)
        cur_len += bsize

    flush_chunk()
    return result


# ============================================================
#         ДЕЛЕНИЕ ОГРОМНОГО ТЕКСТА НА ЧАНКИ
# ============================================================

def split_text_by_max_size(text, min_size, max_size, strict=True):
    """
    Делит текст по словам так, чтобы каждый чанк ≤ max_size.
    """
    words = text.split()
    chunks = []
    cur = []
    cur_len = 0

    for w in words:
        wl = 1
        if cur_len + wl > max_size:
            chunks.append(" ".join(cur))
            cur = [w]
            cur_len = wl
        else:
            cur.append(w)
            cur_len += wl

    if cur:
        chunks.append(" ".join(cur))

    return chunks


# ============================================================
#                ОСНОВНАЯ ФУНКЦИЯ CHUNKING
# ============================================================

def normalize_pre_chunks(pre_chunks, min_size=50, max_size=200, strict=True):
    """
    Объединяет текст, режет большие блоки,
    логически режет таблицы, формирует конечные чанки.
    """

    result_chunks = []
    current_text = []
    current_tables = []
    current_len = 0

    def flush_chunk():
        nonlocal current_text, current_len, current_tables
        if current_text:
            result_chunks.append({
                "text": "\n\n".join(current_text),
                "chunkSize": current_len,
                "tables": current_tables.copy()
            })
            current_text = []
            current_tables = []
            current_len = 0

    # ---------------------------
    # 1. основной цикл
    # ---------------------------
    for item in pre_chunks:

        # ======================================
        # TEXT
        # ======================================
        if item["type"] == "text":
            text = item["content"]
            t_size = tokenize_len(text)

            # если большой текст — режем
            if t_size > max_size:
                pieces = split_text_by_max_size(text, min_size, max_size, strict)

                for part in pieces:
                    psize = tokenize_len(part)
                    if current_len + psize > max_size:
                        flush_chunk()
                    current_text.append(part)
                    current_len += psize
                continue

            # обычный текст
            if current_len + t_size > max_size:
                flush_chunk()

            current_text.append(text)
            current_len += t_size
            continue

        # ======================================
        # TABLE
        # ======================================
        elif item["type"] == "table":
            table_text = convert_table_to_text(item["content"])
            table_parts = split_table_logically(table_text, min_size, max_size)

            for part in table_parts:
                part_size = tokenize_len(part)
                part_hash = hash_text(part)

                if current_len + part_size > max_size:
                    flush_chunk()

                current_text.append(part)
                current_tables.append(part_hash)
                current_len += part_size

            continue

    flush_chunk()

    # ======================================
    # Финальное объединение маленьких чанков
    # ======================================
    final = []
    buffer = None

    for ch in result_chunks:
        if ch["chunkSize"] < min_size:
            if buffer is None:
                buffer = ch
            else:
                merged = {
                    "text": buffer["text"] + "\n\n" + ch["text"],
                    "chunkSize": buffer["chunkSize"] + ch["chunkSize"],
                    "tables": buffer["tables"] + ch["tables"]
                }
                buffer = merged
        else:
            if buffer:
                if buffer["chunkSize"] + ch["chunkSize"] <= max_size:
                    merged = {
                        "text": buffer["text"] + "\n\n" + ch["text"],
                        "chunkSize": buffer["chunkSize"] + ch["chunkSize"],
                        "tables": buffer["tables"] + ch["tables"]
                    }
                    final.append(merged)
                else:
                    final.append(buffer)
                    final.append(ch)
                buffer = None
            else:
                final.append(ch)

    if buffer:
        final.append(buffer)

    return final

# %%
{"type": ("text"/"table"), "content": (str/array)}

# %%
from object.LoadDOC_RTF import parse_doc_or_rtf

data_test = parse_doc_or_rtf("../dataset/НП-064-17.rtf")
# Out:
# Error: source file could not be loaded
# ---------------------------------------------------------------------------
# PackageNotFoundError                      Traceback (most recent call last)
# Cell In[12], line 3
#       1 from object.LoadDOC_RTF import parse_doc_or_rtf
# ----> 3 data_test = parse_doc_or_rtf("../dataset/НП-064-17.rtf")
#
# File ~/Git/NeuroFile/ai-agent/object/LoadDOC_RTF.py:26, in parse_doc_or_rtf(file_path)
#      23     tmp_docx = os.path.join(tmpdir, filename.replace(ext, ".docx"))
#      25 # Парсинг docx
# ---> 26 blocks = parse_docx(tmp_docx)
#      28 return blocks
#
# File ~/Git/NeuroFile/ai-agent/object/LoadDOCX.py:74, in parse_docx(file_path)
#      73 def parse_docx(file_path):
# ---> 74     doc = Document(file_path)
#      75     blocks = []
#      77     for element in doc.element.body:
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/ml-hack-VN-v4/lib/python3.11/site-packages/docx/api.py:27, in Document(docx)
#      20 """Return a |Document| object loaded from `docx`, where `docx` can be either a path
#      21 to a ``.docx`` file (a string) or a file-like object.
#      22
#      23 If `docx` is missing or ``None``, the built-in default document "template" is
#      24 loaded.
#      25 """
#      26 docx = _default_docx_path() if docx is None else docx
# ---> 27 document_part = cast("DocumentPart", Package.open(docx).main_document_part)
#      28 if document_part.content_type != CT.WML_DOCUMENT_MAIN:
#      29     tmpl = "file '%s' is not a Word file, content type is '%s'"
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/ml-hack-VN-v4/lib/python3.11/site-packages/docx/opc/package.py:126, in OpcPackage.open(cls, pkg_file)
#     123 @classmethod
#     124 def open(cls, pkg_file: str | IO[bytes]) -> Self:
#     125     """Return an |OpcPackage| instance loaded with the contents of `pkg_file`."""
# --> 126     pkg_reader = PackageReader.from_file(pkg_file)
#     127     package = cls()
#     128     Unmarshaller.unmarshal(pkg_reader, package, PartFactory)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/ml-hack-VN-v4/lib/python3.11/site-packages/docx/opc/pkgreader.py:22, in PackageReader.from_file(pkg_file)
#      19 @staticmethod
#      20 def from_file(pkg_file):
#      21     """Return a |PackageReader| instance loaded with contents of `pkg_file`."""
# ---> 22     phys_reader = PhysPkgReader(pkg_file)
#      23     content_types = _ContentTypeMap.from_xml(phys_reader.content_types_xml)
#      24     pkg_srels = PackageReader._srels_for(phys_reader, PACKAGE_URI)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/ml-hack-VN-v4/lib/python3.11/site-packages/docx/opc/phys_pkg.py:21, in PhysPkgReader.__new__(cls, pkg_file)
#      19         reader_cls = _ZipPkgReader
#      20     else:
# ---> 21         raise PackageNotFoundError("Package not found at '%s'" % pkg_file)
#      22 else:  # assume it's a stream and pass it to Zip reader to sort out
#      23     reader_cls = _ZipPkgReader
#
# PackageNotFoundError: Package not found at '/var/folders/xl/0bqpzy9s59s2vz7tlq_2f5rc0000gn/T/tmpsyamnpsc/НП-064-17.docx'

# %%
tess = normalize_pre_chunks(data_test, 50, 120)

# %%
for i in tess:
    if i["chunkSize"] > 120:
        print(i)

# %%
from object.LoadDOC_RTF import parse_doc_or_rtf

# %%
pre_chunk = parse_doc_or_rtf('./dataset/НП-064-17.rtf')
# Out:
# convert /Users/odner/Git/NeuroFile/ai-agent/dataset/НП-064-17.rtf as a Writer document -> /private/var/folders/xl/0bqpzy9s59s2vz7tlq_2f5rc0000gn/T/tmpa5pav0qk/НП-064-17.docx using filter : Office Open XML Text

# %%
tess = normalize_pre_chunks(pre_chunk, 100, 200)

# %%
tess
# Out:
# [{'text': 'ФЕДЕРАЛЬНАЯ СЛУЖБА ПО ЭКОЛОГИЧЕСКОМУ, ТЕХНОЛОГИЧЕСКОМУ И АТОМНОМУ НАДЗОРУ ПРИКАЗ от 30 ноября 2017 года N 514 Об утверждении федеральных норм и правил в области использования атомной энергии "Учет внешних воздействий природного и техногенного происхождения на объекты использования атомной энергии" В соответствии со статьей 6 Федерального закона от 21 ноября 1995 г. N 170-ФЗ "Об использовании атомной энергии" (Собрание законодательства Российской Федерации, 1995, N 48, ст.4552; 1997, N 7, ст.808; 2001, N 29, ст.2949; 2002, N 1, ст.2; N 13, ст.1180; 2003, N 46, ст.4436; 2004, N 35, ст.3607; 2006, N 52, ст.5498; 2007, N 7, ст.834; N 49, ст.6079; 2008, N 29, ст.3418; N 30, ст.3616; 2009, N 1, ст.17; N 52, ст.6450; 2011, N 29, ст.4281; N 30, ст.4590, ст.4596; N 45, ст.6333; N 48, ст.6732; N 49, ст.7025; 2012, N 26, ст.3446; 2013, N 27, ст.3451; 2016, N 14, ст.1904; N 15, ст.2066; N 27, ст.4289), подпунктом 5.2.2.1 пункта 5 Положения о Федеральной службе по экологическому, технологическому и атомному надзору, утвержденного постановлением Правительства Российской Федерации от 30 июля 2004 г. N 401 (Собрание законодательства Российской Федерации, 2004, N 32, ст.3348; 2006, N 5, ст.544; N 23, ст.2527; N 52, ст.5587; 2008, N 22, ст.2581; N 46, ст.5337; 2009,',
#   'chunkSize': 200,
#   'tables': []},
#  {'text': 'N 6, ст.738; N 33, ст.4081; N 49, ст.5976; 2010, N 9, ст.960; N 26, ст.3350; N 38, ст.4835; 2011, N 14, ст.1935; N 41, ст.5750; N 50, ст.7385; 2012, N 29, ст.4123; N 42, ст.5726; 2013, N 12, ст.1343; N 45, ст.5822; 2014, N 2, ст.108; N 35, ст.4773; 2015, N 2, ст.491; N 4, ст.661; 2016, N 28, ст.4741; N 48, ст.6789; 2017, N 12, ст.1729; N 26, ст.3847), приказываю: Утвердить прилагаемые федеральные нормы и правила в области использования атомной энергии "Учет внешних воздействий природного и техногенного происхождения на объекты использования атомной энергии" (НП-064-17).\n\nРуководитель\n\nА.В.Алёшин\n\nЗарегистрировано в Министерстве юстиции\n\nРоссийской Федерации',
#   'chunkSize': 104,
#   'tables': []},
#  {'text': '26 декабря 2017 года, регистрационный N 49461 УТВЕРЖДЕНЫ приказом Федеральной службы по экологическому, технологическому и атомному надзору от 30 ноября 2017 года N 514 Федеральные нормы и правила в области использования атомной энергии "Учет внешних воздействий природного и техногенного происхождения на объекты использования атомной энергии" (НП-064-17) I. Назначение и область применения 1.1. Настоящие федеральные нормы и правила в области использования атомной энергии "Учет внешних воздействий природного и техногенного происхождения на объекты использования атомной энергии" (НП-064-17) (далее - Правила) разработаны в соответствии со статьей 6 Федерального закона от 21 ноября 1995 г. N 170-ФЗ "Об использовании атомной энергии", постановлением Правительства Российской Федерации от 1 декабря 1997 г. N 1511 "Об утверждении Положения о разработке и утверждении федеральных норм и правил в области использования атомной энергии" (Собрание законодательства Российской Федерации, 1997, N 49, ст.5600; 2012, N 51, ст.7203).',
#   'chunkSize': 136,
#   'tables': []},
#  {'text': '1.2. Правила устанавливают требования к учёту внешних воздействий природного и техногенного происхождения (далее - внешних воздействий) на ядерные установки, радиационные источники, пункты хранения ядерных материалов и радиоактивных веществ, пункты захоронения радиоактивных отходов I и II категории по потенциальной радиационной опасности (объекты использования атомной энергии, далее - ОИАЭ) при их размещении, проектировании, сооружении, эксплуатации и выводе из эксплуатации (закрытии), в том числе требования к: инженерным изысканиям и исследованиям процессов, явлений и факторов природного и техногенного происхождения; обеспечению устойчивости и безопасности ОИАЭ при внешних воздействиях; инженерной защите ОИАЭ от внешних воздействий; мониторингу внешних воздействий.\n\n1.3. Правила не распространяются: на транспортные и транспортабельные ядерные установки, а также транспортные и транспортабельные средства для транспортирования ядерных материалов, радиоактивных веществ и радиоактивных отходов; на внешние воздействия от преднамеренных (террористических, диверсионных) действий и в период военных действий.\n\n1.4. Порядок приведения ОИАЭ в соответствие с требованиями настоящих Правил, в том числе сроки и объем необходимых мероприятий, определяется в каждом конкретном случае в условиях действия лицензии на размещение, сооружение, эксплуатацию или вывод из эксплуатации (закрытие).\n\n1.5. Перечень сокращений, термины и определения приведены в приложениях N 1 и N 2 настоящих Правил.\n\nII. Основные положения',
#   'chunkSize': 185,
#   'tables': []},
#  {'text': '2.1. При проведении инженерных изысканий и исследований района размещения и площадки ОИАЭ должна быть установлена номенклатура процессов, явлений и факторов природного и техногенного происхождения, способных оказать влияние на безопасность ОИАЭ.\n\n2.1.1. Гидрометеорологические процессы и явления: наводнение; цунами; ледовые явления на водотоках; режим прибрежной зоны водных объектов; сейши; приливы и отливы; изменение водных ресурсов: экстремально низкий сток, аномальное снижение уровня воды; смерч; ветер, ураган; тропический циклон (тайфун); атмосферные осадки; экстремальные снегопады и снегозапасы; температура воздуха; лавина снежная; гололед; удар молнии.\n\n2.1.2. Геологические и инженерно-геологические процессы и явления: сейсмотектонические разрывные смещения, сейсмодислокации, сейсмотектонические поднятия, опускания блоков земной коры; современные дифференцированные движения земной коры, тектонический крип; новейшие движения земной коры; остаточные сейсмодеформации земной коры; землетрясение (любого генезиса); извержение вулкана; грязевой вулканизм; оползни; обвалы и оползни-обвалы; сели; лавины снежно-каменные и щебнисто-глыбовые; размывы берегов, склонов, русел; оседания и провалы; размывы подземные, в том числе проявления карста; мерзлотно-геологические (криогенные) процессы; деформации специфических грунтов (карст, термокарст, разжижение, солифлюкция, суффозионные процессы); эоловые процессы (дефляция, перевевание, барханообразование); коррозионная агрессивность грунтов и подземных вод; глубина залегания уровня грунтовых вод; климатическая (солнечная) термодеструкция; атмосферная коррозия.\n\n2.1.3. Факторы, создающие внешние биологические явления.',
#   'chunkSize': 180,
#   'tables': []},
#  {'text': '2.1.4. Факторы, создающие внешние воздействия техногенного происхождения (техногенные факторы): падение летательного аппарата и других летящих предметов; пожар по внешним причинам; взрыв на объекте; радиационная авария; выбросы взрывоопасных, воспламеняющихся, токсичных паров, газов и аэрозолей в атмосферу, взрыв дрейфующих облаков; коррозионные жидкие сбросы в поверхностные и грунтовые воды; электромагнитное излучение; разлив масел и нефтепродуктов на прибрежных поверхностях водных объектов; прорыв естественных или искусственных водохранилищ.\n\n2.1.5. В проекте ОИАЭ должны быть установлены и обоснованы значения параметров внешних природных воздействий с оцененною вероятностью возникновения на интервале в один год 10 и выше и внешние техногенные воздействия с оцененною вероятностью возникновения на интервале в один год 10 и выше.\n\n2.2. При размещении и проектировании ОИАЭ для процессов, явлений и факторов природного и техногенного происхождения должна быть установлена степень опасности ( приложение N 3 настоящих Правил).\n\nНоменклатура процессов, явлений и факторов природного и техногенного происхождения, параметры их воздействий и степень опасности должны обосновываться в проектной документации (далее - проект ОИАЭ) и приводиться в отчете по обоснованию безопасности (далее - ООБ).',
#   'chunkSize': 164,
#   'tables': []},
#  {'text': '2.3. В зависимости от степени опасности внешних воздействий на ОИАЭ, приведенных в приложении N 3 настоящих Правил, должен быть установлен и обоснован класс рассматриваемой площадки ОИАЭ: площадка ОИАЭ класса А - площадка, на которой отсутствуют внешние воздействия I и II степени опасности, но имеются внешние воздействия III степени; площадка ОИАЭ класса Б - площадка, на которой отсутствуют внешние воздействия I степени опасности, но имеются внешние воздействия II и III степеней опасности; площадка ОИАЭ класса В - площадка, на которой имеются внешние воздействия I, II и III степени опасности.\n\n2.4. В целях снижения негативных последствий от влияния внешних воздействий при выборе площадки ОИАЭ должно отдаваться предпочтение площадкам классов А и Б.\n\n2.5. В проекте ОИАЭ должны быть предусмотрены и обоснованы технические средства и организационные мероприятия, предназначенные для обеспечения стойкости систем и элементов ОИАЭ, важных для безопасности, к влиянию внешних воздействий, установленных в районе и на площадке размещения ОИАЭ.\n\n2.6. При сооружении, эксплуатации и выводе из эксплуатации (закрытии) ОИАЭ должны быть реализованы и выполняться организационные и технические меры, предназначенные для обеспечения стойкости систем и элементов ОИАЭ, важных для безопасности, к влиянию внешних воздействий, установленных в районе размещения ОИАЭ и на площадке ОИАЭ.',
#   'chunkSize': 190,
#   'tables': []},
#  {'text': '2.7. При выполнении детерминистических и вероятностных анализов безопасности должны быть учтены внешние воздействия природного и техногенного характера. В составе исходных событий при детерминистическом анализе проектных аварий должны учитываться внешние воздействия природного происхождения, имеющие оцененную вероятность возникновения на интервале в один год 10 или выше, а также внешние воздействия техногенного происхождения, имеющие оцененную вероятность возникновения на интервале в один год 10 или выше.\n\n2.8. В проекте ОИАЭ должен быть выполнен анализ запроектных аварий, включая возможные запроектные аварии, вызванные внешними воздействиями с интенсивностью превышающей интенсивность воздействий, учитываемых в проекте ОИАЭ, а также сочетания указанных воздействий.\n\n2.9. В проекте ОИАЭ должны быть представлены сведения о взаимосвязанных процессах, явлениях и факторах природного и техногенного происхождения, выявленных в процессе проведения инженерных изысканий и исследований. Примерный перечень внешних природных и техногенных взаимосвязанных процессов, явлений и факторов приведен в приложении N 4 настоящих Правил. Должно быть обосновано наличие или отсутствие таких процессов, явлений и факторов. В случае наличия взаимосвязанных или взаимообусловленных процессов и явлений природного и техногенного происхождения должен быть выполнен анализ их влияния на безопасности АС.\n\n2.10. Оценка стойкости зданий, сооружений, систем (элементов) ОИАЭ при внешних воздействиях в проекте ОИАЭ должна выполняться на основе консервативного подхода.',
#   'chunkSize': 190,
#   'tables': []},
#  {'text': '2.11. В проекте ОИАЭ должны быть предусмотрены системы автоматической или автоматизированной регистрации интенсивности внешних воздействий, влияющих на безопасность ОИАЭ.\n\n2.12. Для ядерных установок, в проекте которых приняты проектные внешние воздействия I степени опасности с динамическим характером их реализации, в проекте ОИАЭ должна предусматриваться система сейсмометрического контроля и сигнализации, связанная с системой автоматизированной остановки ядерной установки.\n\n2.13. Системы автоматизированного останова ядерных установок должны выполнять свои заданные функции в случаях, если будут превышены контрольные уровни интенсивностей внешних воздействий с динамическим характером их реализации в местах установки датчиков (индикаторов) регистрации внешних воздействий. При этом должны быть предприняты меры по идентификации и установлению типа внешних воздействий и меры по предотвращению ложного срабатывания систем автоматизированного останова.\n\n2.14. ОИАЭ должны быть остановлены автоматически или в ручном режиме после прохождения на площадке внешнего воздействия природного и техногенного происхождения с динамическим характером реализации (землетрясения, внешнего взрыва и падения летательного аппарата) в случаях, когда будут превышены установленные в проекте контрольные уровни интенсивностей внешних воздействий. Количественные значения параметров, принятых в качестве контрольных уровней, должны быть обоснованы в проекте и приведены в отчетах по обоснованию безопасности ОИАЭ.',
#   'chunkSize': 176,
#   'tables': []},
#  {'text': '2.15. Необходимо проводить обследования и анализ состояния зданий, сооружений, систем, элементов ОИАЭ для оценки возможности его дальнейшей безопасной эксплуатации, если на площадке размещения ОИАЭ реализовался процесс, явление или фактор природного или техногенного происхождения динамического характера, интенсивность которого соответствует I или II степени опасности.\n\nIII. Требования к выявлению и оценке параметров внешних воздействий и их учету в проекте 3.1. При проведении инженерных изысканий и исследований в районе размещения ОИАЭ и на площадке ОИАЭ должны учитываться и идентифицироваться внешние воздействия на основе информации о положении источника внешнего воздействия, его интенсивности и вероятности возникновения.\n\nИсточники информации для выявления и идентификации внешних процессов, явлений и факторов природного и техногенного происхождения приведены в приложении N 5 настоящих Правил. Перечень основных параметров внешних воздействий, процессов, явлений и факторов природного и техногенного происхождения, учитываемых в проекте ОИАЭ, приведен в приложении N 6 к настоящим Правилам.\n\n3.2. В проекте ОИАЭ должны быть учтены результаты инженерных изысканий и исследований в районе размещения ОИАЭ и на площадке ОИАЭ, содержащие информацию о параметрах процессов, явлений и факторов природного и техногенного происхождения с учетом: изученности территории района размещения ОИАЭ и площадки ОИАЭ; планировки и условий размещения ОИАЭ; срока сооружения ОИАЭ; сроков эксплуатации и вывода из эксплуатации ОИАЭ.',
#   'chunkSize': 195,
#   'tables': []},
#  {'text': '3.3. Объем и состав выполняемых инженерных изысканий и исследований района размещения ОИАЭ и площадки ОИАЭ должны быть достаточны для: выявления внешних воздействий, влияющих на безопасность ОИАЭ; определения максимальных значений интенсивности внешних воздействий, вероятности их возникновения, безопасного расстояния от источников внешних воздействий до площадки ОИАЭ; установления степени опасности внешних воздействий и класса площадки ОИАЭ; учета взаимосвязи внешних воздействий и прогноза их развития при сооружении, эксплуатации и выводе из эксплуатации ОИАЭ.\n\nРезультаты инженерных изысканий и исследований района размещения ОИАЭ и площадки ОИАЭ должны отображаться в ООБ ОИАЭ и актуализироваться по результатам мониторинга параметров процессов явлений и факторов природного и техногенного происхождения при сооружении, эксплуатации и выводе из эксплуатации ОИАЭ в соответствии с программой мониторинга.\n\n3.4. Для каждого учитываемого в проекте ОИАЭ внешнего воздействия должен составляться отдельный перечень зданий, сооружений, систем и элементов ОИАЭ, подлежащих анализу стойкости к этому внешнему воздействию.\n\nВ перечень должны включаться здания, сооружения, строительные конструкции, системы и элементы ОИАЭ, повреждение которых в результате внешнего воздействия может привести к отказу систем и элементов, важных для безопасности ОИАЭ.',
#   'chunkSize': 167,
#   'tables': []},
#  {'text': '3.5. Анализы стойкости включенных в перечень зданий, сооружений, систем (элементов) ОИАЭ должны выполняться для каждого независимого внешнего воздействия и с учетом возможного его взаимообусловленного сочетания и взаимодействия с другими внешними воздействиями, принятыми в проекте.\n\n3.6. В проекте ОИАЭ для включенных в перечень зданий, сооружений, систем (элементов) ОИАЭ должны устанавливаться и обосновываться проектные пределы стойкости при нагрузках от внешних воздействий, включая нагрузки от эффектов их взаимообусловленного сочетания и взаимодействия. Проектные критерии стойкости зданий, сооружений, систем (элементов) ОИАЭ должны быть обоснованы расчетными и экспериментальными методами с учетом конструкторских и планировочных решений, опыта эксплуатации ОИАЭ.\n\n3.7. Результаты анализа стойкости зданий, сооружений, систем и элементов ОИАЭ согласно перечню, упомянутому в п.3.4 настоящих Правил, должны содержать обоснования непревышения проектных пределов: относительных и абсолютных деформаций строительных конструкций; осадки и крена зданий и сооружений с учетом современных движений земной коры (поверхности) на площадке размещения; термической и коррозионной стойкости материалов; прочности и долговечности; герметичности и непроницаемости (газо-, пыле- и дымонепроницаемости) внутренних объемов зданий и сооружений; характеризующих работоспособность строительных конструкций, систем (элементов); огнестойкости.\n\nПеречень анализируемых проектных пределов и объем проводимых анализов обосновывается в проекте ОИАЭ.\n\nЛогическая схема процедуры анализа безопасности ОИАЭ при природных и техногенных воздействиях приведена в приложении N 7 настоящих Правил.',
#   'chunkSize': 194,
#   'tables': []},
#  {'text': '3.8. Анализ стойкости зданий, сооружений, систем (элементов) должен выполняться с использованием апробированных методов анализа и расчета, и аттестованными программными средствами.\n\n3.9. Для каждого вновь проектируемого ОИАЭ, безопасность должна обеспечиваться с учетом: максимальных горизонтальных ускорений не менее 0,1 g на отметке свободной поверхности грунта площадки; нагрузок ВУВ на системы и элементы ОИАЭ, подверженные воздействию ВУВ, с давлением во фронте не менее 10 кПа, время фазы сжатия до 1 с; обеспечения не ниже I степени огнестойкости зданий, сооружений и пожарных отсеков, содержащих системы (элементы) безопасности; стойкости строительных конструкций локализующих систем к локальным ударным нагрузкам от падения летательных аппаратов и других летящих предметов, равным в зоне контакта ударной нагрузке, не менее возникающей при падении легкого самолета (5 т); пространственного физического разделения каналов систем безопасности.\n\nIV. Требования к инженерной защите объекта использования атомной энергии 4.1. В проекте ОИАЭ должны быть разработаны организационные и технические меры по инженерной защите, предупреждению и снижению негативных последствий внешних природных и техногенных воздействий I и II степени опасности с учетом сценариев их развития и их взаимосвязи.',
#   'chunkSize': 167,
#   'tables': []},
#  {'text': 'В местах возможного проявления в районе размещения ОИАЭ и на площадке ОИАЭ внешних воздействий I и II степени опасности должны выполняться мероприятия по исключению возникновения на путях эвакуации временных преград (оползней, лавин, затоплений, провалов, тектонических нарушений) и предусматриваться альтернативные пути эвакуации.\n\n4.2. Организационные и технические меры по инженерной защите ОИАЭ от внешних воздействий должны быть обоснованы в проекте ОИАЭ. Технические меры по инженерной защите ОИАЭ должны приниматься с учетом опыта их применения и опыта анализа последствий имевших место внешних воздействий высокой интенсивности. Достаточность принятых технических решений по инженерной защите ОИАЭ должна быть обоснована в проекте ОИАЭ с учетом максимальных значений параметров внешних воздействий, учитываемых в проекте ОИАЭ, расчетными методами и испытаниями зданий, сооружений, систем (элементов) ОИАЭ, а также с учетом опыта эксплуатации.\n\nПеречень организационных и технических мер по инженерной защите ОИАЭ от внешних воздействий обоснованный в проекте ОИАЭ должен быть отражен в ООБ ОИАЭ. Примерный перечень организационных и технических мер по инженерной защите ОИАЭ от внешних воздействий приведен в приложении N 8 настоящих Правил.',
#   'chunkSize': 164,
#   'tables': []},
#  {'text': 'V. Требования к учету внешних воздействий при эксплуатации и выводе из эксплуатации (закрытии) объекта использования атомной энергии 5.1. Для обеспечения безопасности в процессе ввода в эксплуатацию ОИАЭ должны определяться динамические характеристики (затухание и частоты собственных колебаний) систем и элементов (кроме зданий и сооружений), важных для безопасности. Состав и объем экспериментального определения динамических характеристик систем и элементов, важных для безопасности, должны устанавливаться и обосновываться в проекте ОИАЭ.\n\n5.2. Для эксплуатируемых ОИАЭ динамические характеристики систем и элементов, важных для безопасности, должны быть определены расчетом, а затем подтверждены исследованиями или испытаниями во время эксплуатации на остановленном и приведенном в безопасное состояние ОИАЭ (например, в период плановой остановки ОИАЭ). Данные об уточненных динамических характеристиках компонент (систем, элементов) ОИАЭ должны использоваться при проведении анализов безопасности ОИАЭ, а также отражаться в соответствующих отчетах по обоснованию безопасности.\n\n5.3. Технические меры по защите важных для безопасности зданий, сооружений, систем (элементов) ОИАЭ от внешних воздействий должны быть разработаны в проекте, реализованы на этапе сооружения и выполняться при эксплуатации и выводе из эксплуатации (закрытии) ОИАЭ.\n\n5.4. В проекте вывода из эксплуатации (закрытии) ОИАЭ должны предусматриваться меры по обеспечению стойкости зданий, сооружений, строительных конструкций, систем и элементов ОИАЭ с учетом параметров внешних воздействий, прогнозируемых на этапе вывода из эксплуатации (закрытия) ОИАЭ.',
#   'chunkSize': 200,
#   'tables': []},
#  {'text': '5.5. Для оценки возможности дальнейшей безопасной эксплуатации ОИАЭ после реализации на площадке внешнего воздействия I или II степени опасности, должно быть проведено обследование состояния зданий, сооружений, систем и элементов ОИАЭ и выполнен анализ результатов обследования.\n\n5.6. При эксплуатации и выводе из эксплуатации (закрытии) ОИАЭ мониторинг параметров процессов, явлений и факторов природного и техногенного происхождения должен осуществляться путем: оценки и прогноза технического состояния зданий, сооружений и строительных конструкций, важных для безопасности, включая оценки и прогнозы кренов и осадок этих зданий; периодических проверок состояния и предусмотренных проектом испытаний защитных средств (например, сейсмоизоляции, демпфирующих устройств), систем противопожарной защиты, обвалований территории ОИАЭ.\n\nVI. Требования к мониторингу внешних воздействий 6.1. В районе и на площадке размещения ОИАЭ с начала сооружения ОИАЭ, при его эксплуатации и выводе из эксплуатации (закрытии) должен выполняться мониторинг параметров процессов, явлений и факторов природного воздействия, а также периодический контроль параметров внешних воздействий техногенного происхождения, состояния оснований, строительных конструкций и систем инженерно-технического обеспечения.',
#   'chunkSize': 151,
#   'tables': []},
#  {'text': '6.2. Мониторинг параметров процессов, явлений и факторов природного и техногенного происхождения должен осуществляться с учетом данных глобальных и единых государственных систем мониторинга, действующих на территории Российской Федерации, и включать следующие виды мониторинга: радиационный; метеорологический; аэрологический; гидрологический; гидрогеологический; геотехнический мониторинг грунтов основания, включая наблюдения за кренами и осадками зданий и сооружений ОИАЭ; сейсмологический; геодинамический мониторинг современных движений земной поверхности; периодический контроль параметров внешних техногенных воздействий.\n\n6.3. Объем и состав мониторинга внешних природных воздействий, а также необходимых для его выполнения систем мониторинга и контроля техногенных воздействий, должны быть установлены и обоснованы в проекте ОИАЭ с учетом результатов инженерных изысканий и исследований, в составе которых выполняются режимные наблюдения параметров процессов, явлений и факторов природного и техногенного происхождения.\n\n6.4. Если на площадке размещения ОИАЭ возможны процессы и явления природного происхождения I и II степеней опасности, то системы мониторинга для оценки их параметров должны быть реализованы и функционировать до ввода в эксплуатацию ОИАЭ.\n\n6.5. Системы мониторинга должны выполнять свои функции в соответствии с требованиями проекта на всех этапах жизненного цикла ОИАЭ.\n\n6.6. Информация о внешних воздействиях природного и техногенного характера должна актуализироваться на всех этапах жизненного цикла ОИАЭ и отражаться в ООБ ОИАЭ, в том числе при проведении периодической оценки безопасности ОИАЭ.',
#   'chunkSize': 197,
#   'tables': []},
#  {'text': '6.7. Для мониторинга параметров процессов, явлений и факторов природного и техногенного происхождения должны использоваться средства измерений и измерительные системы утвержденного типа, прошедшие поверку. Результаты измерений должны быть выражены в единицах величин, допущенных к применению в Российской Федерации. Средства измерений и измерительные системы для мониторинга и периодического контроля параметров процессов, явлений и факторов должны проходить поверки. Частота поверок должна устанавливаться в проектной документации систем мониторинга и периодического контроля и быть достаточной для обеспечения гарантий их безотказной работы в период между поверками.\n\n6.8. Результаты мониторинга параметров процессов и явлений природного происхождения должны использоваться совместно с данными государственных систем мониторинга, которые имеются на территории Российской Федерации в районе размещения площадки ОИАЭ.\n\nПриложение N 1 к федеральным нормам и правилам в области использования атомной энергии "Учет внешних воздействий природного и техногенного происхождения на объекты использования атомной энергии", утвержденным приказом Федеральной службы по экологическому, технологическому и атомному надзору от 30 ноября 2017 года N 514 Перечень сокращений',
#   'chunkSize': 152,
#   'tables': []},
#  {'text': '| АС  | -  | атомная станция |\n| ВАБ  | -  | вероятностный анализ безопасности |\n| ВУВ  | -  | воздушная ударная волна |\n| ЛКП  | -  | лакокрасочные покрытия |\n| МРЗ  | -  | максимальное расчетное землетрясение |\n| MSK-64  | -  | шкала сейсмической интенсивности (Медведева - Шпонхойера - Карника) |\n| ОИАЭ  | -  | объект использования атомной энергии |\n| ООБ  | -  | отчет по обоснованию безопасности |\n|  | -  | максимальное ускорение грунта на свободной поверхности  |\n\nПриложение N 2 к федеральным нормам и правилам в области использования атомной энергии "Учет внешних воздействий природного и техногенного происхождения на объекты использования атомной энергии", утвержденным приказом Федеральной службы по экологическому, технологическому и атомному надзору от 30 ноября 2017 года N 514 Термины и определения 1. Биологические явления - явления, происходящие в живой природе и характеризующиеся ритмичностью и периодичностью.\n\n2. Воздействие природного происхождения - воздействие, вызванное внешними по отношению к ОИАЭ процессами, явлениями и факторами природного происхождения.',
#   'chunkSize': 165,
#   'tables': ['b5cbf0a7e6abe714b41f5fd419652de5']},
#  {'text': '3. Воздействие техногенного происхождения - внешнее по отношению к ОИАЭ воздействие, вызванное непосредственно деятельностью человека или как результат использования им техники и технологий на объектах находящихся как за пределами площадки ОИАЭ, так и в её пределах.* * Примерами источников, находящихся в пределах площадки ОИАЭ, являются блоки АС по отношению к другим блокам АС той же многоблочной АС, либо общестанционное оборудование АС по отношению к блоку АС.\n\n4. Градиент скорости тектонических движений - изменение амплитуды тектонического перемещения маркирующей поверхности на единице расстояния в единицу времени.\n\n5. Градоопасность территории - характеристика территории, определяемая частотой выпадения града, площадями градобитий, степенью повреждений и потерями от града.\n\n6. Запроектная авария - авария, вызванная не учитываемыми для проектных аварий исходными событиями или сопровождающаяся дополнительными по сравнению с проектными авариями отказами систем безопасности сверх единичного отказа, реализацией ошибочных решений работников (персонала).\n\n7. Инженерная защита ОИАЭ - комплекс технических и организационных мер по защите зданий, сооружений, систем, элементов ОИАЭ и работников (персонала), предупреждению аварий, приводящих к выбросам радионуклидов в атмосферу и/или сбросам радионуклидов в окружающую среду, предупреждения или снижения социального и экономического ущерба при внешних воздействиях природного и/или техногенного происхождения.\n\n8. Новейшие движения земной коры - движения земной коры, происшедшие в неоген-четвертичный период геологического развития Земли.',
#   'chunkSize': 198,
#   'tables': []},
#  {'text': '9. Площадка ОИАЭ - территория в пределах охраняемого периметра, где размещаются здания и сооружения ОИАЭ.\n\n10. Пожар по внешним причинам - пожар, возникший за пределами ОИАЭ, в результате которого может быть оказано внешнее воздействие на ОИАЭ.\n\n11. Провал - опускание земной поверхности в результате изменения свойств пород земной коры.\n\n12. Пыльная (песчаная) буря - разновидность суховея, отличающаяся сильным ветром, переносящая на большие расстояния огромные массы частиц почвы и песка.\n\n13. Расстояние безопасное - удаление источника опасности от ОИАЭ, за пределами которого можно пренебречь влияниями данного источника внешних воздействий природного или техногенного происхождения на безопасность ОИАЭ.\n\n14. Район размещения ОИАЭ - территория, включающая площадку ОИАЭ, на которой возможны явления, процессы и факторы природного и техногенного происхождения, способные оказать влияние на безопасность ОИАЭ.\n\n15. Стойкость (устойчивость) системы (элемента) при внешних воздействиях - свойство системы (элемента) выполнять функции, связанные с обеспечением безопасности ОИАЭ, при учитываемых в проекте ОИАЭ внешних воздействиях природного и/или техногенного происхождения (сейсмостойкость, вибростойкость, коррозионная стойкость).',
#   'chunkSize': 155,
#   'tables': []},
#  {'text': 'Приложение N 3 к федеральным нормам и правилам в области использования атомной энергии "Учет внешних воздействий природного и техногенного происхождения на объекты использования атомной энергии", утвержденным приказом Федеральной службы по экологическому, технологическому и атомному надзору от 30 ноября 2017 года N 514 Номенклатура внешних природных и техногенных процессов, явлений и факторов, их возможные воздействия и степени опасности',
#   'chunkSize': 57,
#   'tables': []},
#  {'text': '| Процесс, явление и фактор  | Возможные воздействия на площадку ОИАЭ, включая ОИАЭ  | Значения параметров, согласно которым осуществляется классификация степеней опасности  | Степень опасности по последствиям воздействия на ОИАЭ  |\n| ________________ Значения параметров соответствуют вероятности 10 и выше для факторов природного происхождения и вероятности 10 и выше для факторов техногенного происхождения. |\n| I. Гидрометеорологические процессы и явления  |\n| Наводнение  | Затопление площадки размещения ОИАЭ Гидрохимические и динамические воздействия на здания, сооружения и сети  | Уровень затопления выше планировочной отметки площадки 1 м и более, или скорость течения воды на площадке равна и более 0,7 м/с  | I  |\n|  |  | Уровень затопления выше планировочной отметки площадки менее 1 м, но более 0,2 м, или скорость течения воды на площадке менее 0,7 м/с  | II  |\n|  | Затопление площадки размещения ОИАЭ  | Уровень затопления выше планировочной отметки площадки 0,2 м и менее  | III  |',
#   'chunkSize': 150,
#   'tables': ['6aba406b3bf020927cf73820d7425a1a']},
#  {'text': '| Цунами  | Накат волны, временное повышение уровня воды в прибрежной зоне суши. Затопление площадки размещения ОИАЭ Откат волны, временное понижение уровня воды в прибрежной зоне водного объекта. Размыв берегов, возможная активизация оползней на крутых берегах. Динамическое воздействие волны на здания и сооружения ОИАЭ  | Уровень затопления от наката волны цунами выше планировочной отметки площадки на 1 м и более  | I  |\n|  | Накат волны, временное повышение уровня воды в прибрежной зоне суши. Затопление площадки размещения ОИАЭ  | Уровень затопления от наката волны цунами выше планировочной отметки площадки менее 1 м, но более 0,2 м  | II  |\n|  | Временное понижение уровня воды в прибрежной зоне водного объекта Динамическое воздействие  | Уровень затопления от наката волны цунами выше планировочной отметки площадки на 0,2 м и менее  | III  |',
#   'chunkSize': 132,
#   'tables': ['92aa2804d5a13530378aab44fd9420ae']},
#  {'text': '| Ледовые явления на водотоках (заторы, зажоры) | Затопление площадки размещения ОИАЭ, динамические воздействия на здания и  | Уровень затопления выше планировочной отметки площадки на 1 м и более  | I  |\n|  | сооружения ОИАЭ при возникновении волны прорыва  |  | \xa0  |\n|  | Затопление площадки размещения ОИАЭ, динамические воздействия на здания и сооружения  | Уровень затопления выше планировочной отметки площадки менее 1 м, но более 0,2 м  | II  |\n|  | ОИАЭ при возникновении волны прорыва, забитие, засорение водоприемных устройств и трубопроводов ОИАЭ за счет нагона шуги - ледяной крошки  | Уровень затопления выше планировочной отметки площадки на 0,2 м и менее  | III  |\n| Режим прибрежной зоны водных объектов  | Затопление площадки размещения ОИАЭ  | Уровень затопления более или равен 1,0 м  | I |\n|  | Динамическое воздействие на  | Уровень затопления менее 1 м, но более 0,2 м  | II  |\n|  | гидротехнические сооружения вертикального и откосного профилей Обтекание преград и сквозных сооружений  | Уровень затопления 0,2 м и менее  | III  |',
#   'chunkSize': 171,
#   'tables': ['f498663956fc2719b18cf3dd2c782bce']},
#  {'text': '| Сейши  | Затопление площадки размещения ОИАЭ  | Уровень затопления выше планировочной отметки площадки на 1 м и более  | I  |\n|  |  | Уровень затопления выше планировочной отметки площадки менее 1 м, но более 0,2 м  | II  |\n|  |  | Уровень затопления выше планировочной отметки площадки на 0,2 м и менее  | III  |\n| Приливы  | Затопление площадки размещения ОИАЭ  | Уровень затопления выше планировочной отметки площадки на 1 м и менее, но более 0,2 м  | I  |\n|  |  | Уровень затопления выше планировочной отметки площадки менее 1 м, но более 0,2 м  | II  |\n|  |  | Уровень затопления выше планировочной отметки площадки на 0,2 м и менее  | III  |\n| Изменение водных ресурсов: экстремально низкий сток, аномальное снижение уровня воды, включая отливы  | Снижение уровней воды в поверхностных источниках технического водоснабжения ОИАЭ  | Снижение уровней воды в поверхностных источниках технического водоснабжения ОИАЭ более чем на 0,2 м относительно минимальных среднемесячных уровней 95% обеспеченности  | II  |\n|  |  | Снижение уровней воды в поверхностных источниках технического водоснабжения ОИАЭ на 0,2 м и менее относительно минимальных среднемесячных уровней 95% обеспеченности  | III  |',
#   'chunkSize': 193,
#   'tables': ['6a3c05ab9cede92ca2d3f59dbfff9a3e']},
#  {'text': '| Смерч  | Ветровой напор на здания и сооружения  | Класс интенсивности смерча F2,00 и выше  | I  |\n|  | Нагрузки от перепада давления между периферией и центром  | Класс интенсивности смерча менее F2,00, но более F0,00  | II  |\n|  | вращения воронки Нагрузки от летящих предметов, увлеченных смерчем Вынос воды из технологических водоемов-охладителей  | Класс интенсивности смерча F0,00  | III  |\n| Ураган  | Ветровой напор Летящие предметы  | Средняя скорость ветра 32 м/с и более при 10-минутном осреднении  | I  |\n| Ветер  | Ветровой напор Летящие предметы  | Средняя скорость ветра менее 32 м/с, но 7 м/с и более при 10-минутном осреднении  | II  |\n|  |  | Средняя скорость ветра менее 7 м/с при 10-минутном осреднении  | III  |\n| Тайфун, тропический циклон  | Ветровой напор на здания и сооружения Ливневые осадки  | Интенсивность дождевых осадков 30 мм/ч и более, скорость ветра 32 м/с и более при 10-минутном осреднении  | I  |',
#   'chunkSize': 158,
#   'tables': ['b1caf81c3271d607d81bbec6bc3e0e47']},
#  {'text': '| Атмосферные осадки  | Затопление площадки размещения  | Интенсивность дождевых осадков 50 мм и более за 12 ч и менее (в селеопасных районах - 30 мм и более за 12 ч и менее)  | I  |\n|  |  | Интенсивность дождевых осадков менее 50 мм, но более 30 мм за 12 ч и менее  | II  |\n|  |  | Интенсивность дождевых осадков 30 мм и менее за 12 ч и менее  | III  |\n| Лавина снежная  | Динамическое давление снега ВУВ  | Глубина вертикального расчленения рельефа 500-1000 м, средняя максимальная высота слоя снега 70-100 см, скорость лавины - 20 м/с и выше, дальность выброса лавины - 1000 м и более  | I  |\n|  | Динамическое давление снега  | Глубина вертикального расчленения рельефа 500 м и менее, средняя максимальная высота слоя снега менее 70 см, скорость лавины - менее 20 м/с, дальность выброса лавины - менее 1000 м.  | II  |',
#   'chunkSize': 153,
#   'tables': ['a64065f2fa1dddd38c2d8c1d6ece699b']},
#  {'text': '| Гололед  | Разрушение опор линий связи и электроснабжения, отказ систем связи, электроснабжения вследствие покрытия их льдом, изморозью  | Толщина стенки гололеда равна или более 25 мм  | I  |\n|  | Утяжеление конструкций сооружений, вследствие  | Толщина стенки гололеда менее 25 мм, но более 3 мм  | II  |\n|  | покрытия их льдом, изморозью  | Толщина стенки гололеда 3 мм и менее  | III  |\n| II. Геологические и инженерно-геологические процессы и явления  |\n| Современные дифференцированные движения земной поверхности, тектонический крип \xa0  | Деформации земной поверхности, изменение напряжённого состояния грунтов основания  | Геодинамические зоны с градиентом скорости современных дифференцированных движений земной поверхности 10 1/год и выше  | I  |\n|  |  | Геодинамические зоны с градиентом скорости современных дифференцированных движений земной поверхности от 10 до 10 1/год  | II  |\n|  |  | Геодинамические зоны с градиентом скорости современных дифференцированных движений земной поверхности менее 10 1/год  | III  |',
#   'chunkSize': 151,
#   'tables': ['aea9bc68917acb856e31ed911cbc3276']},
#  {'text': '| Новейшие (неоген-четвертичные) движения земной коры  | Деформации земной поверхности, изменение напряжённого состояния грунтов основания  | Геодинамические зоны с градиентом скорости новейших движений 10 1/год и более  | I  |\n|  |  | Геодинамические зоны с градиентом скорости новейших движений от 10 до 10 1/год  | II  |\n|  |  | Геодинамические зоны с градиентом скорости новейших движений менее 10 1/год  | III  |\n| Сейсмотектонические разрывные смещения, поднятия, опускания блоков земной коры  | Тектонические разрывы на поверхности, сопровождаемые сильными колебаниями  | Разрывные смещения с амплитудой 0,3 м и более  | I  |\n| Остаточные сейсмодеформации земной коры:  |  |  |  |\n| - в зонах тектонических нарушений шириной более 10 м при землетрясениях интенсивностью не менее VII баллов по шкале MSK-64;  | Трещины, ступенчатые оседания, складки-надвиги, грунтовые извержения, осадки, земляные волны, образующиеся в результате прохождения сейсмических волн  | Смещения с амплитудой 0,3 м и более  | I  |\n| - в зонах обводненных грунтов; \xa0  | Трещины. Оседания. Деформация оснований  | Смещения с амплитудой 0,1 м и более \xa0  | I  |',
#   'chunkSize': 171,
#   'tables': ['f9681b21384390b7bd479ef83b490f80']},
#  {'text': '| - в зонах тектонических нарушений с приостановившимися тектоническими движениями; \xa0  | Неравномерные осадки из-за неоднородности пород в основании сооружений, пересекающих зону  | Уступы в основании менее 0,3 м, но более 0,1 м; смещения с амплитудой менее 0,3 м, но 0,1 м и более \xa0  | II  |\n| - на пологих склонах и участках с признаками сейсмодеформаций при землетрясениях интенсивностью не менее VII баллов по шкале MSK-64;  | Трещины Оседания Деформация грунтовых оснований  | Смещения с амплитудой менее 0,3 м, но более 0,1 м  | II  |\n| - в зонах тектонических нарушений на склонах и низменных участках в  | Деформация грунтовых оснований  | Смещения с амплитудой менее 0,3 м, но 0,1 м и более  | II  |\n| оттаявших грунтах при сотрясениях от мощных взрывов и землетрясений интенсивностью менее VII баллов по шкале MSK-64  | Трещины Оседания Деформация грунтовых оснований  | Смещения с амплитудой менее 0,1 м  | III  |',
#   'chunkSize': 150,
#   'tables': ['b253f79556838f9db6f253ec6f3d20c0']},
#  {'text': '| Землетрясения (любого генезиса)  | Колебания конструкций. Деформации грунтовых оснований  | Интенсивность уровня МРЗ не менее VIII баллов по шкале MSK-64 ( 0,2 g)  | I  |\n|  | Просадки Изменения режима грунтовых вод  | Интенсивность уровня МРЗ VI-VII баллов по шкале MSK-64 (0,05 g < 0,2 g)  | II  |\n|  |  | Интенсивность уровня МРЗ менее VI баллов по шкале MSK-64 (<0,05 g)  | III  |\n| Извержение вулкана:  |  |  |  |\n| - в зоне выброса вулканических бомб, лавовых потоков и взрывных воздействий;  | Смещения грунтовых оснований Ударные и высокотемпературные  |  | I  |\n| - в зоне распространения пеплов, газов и сотрясений  | воздействия Вредные (загрязняющие) вещества  |  | II  |\n| Грязевой вулканизм:  |  |  |  |\n| - в зонах грязевого фонтанирования и газового загрязнения;  | Грязевое затопление Загазованность Температурные воздействия Деформации грунтовых оснований  | Уровень затопления более или равен 0,5 м  | I  |\n| - в зонах грязевых потоков  | Грязевое затопление  | Уровень затопления менее 0,5 м  | II  |\n| Оползни, движущиеся и приостановившиеся:  |  |  |  |',
#   'chunkSize': 179,
#   'tables': ['df41bb93c90dca69ee3985565951add9']},
#  {'text': '| - с глубиной захвата более 5 м  | Смещение грунтов оснований  | Площадь смещающейся массы 10000 м и более  | I  |\n| - с глубиной захвата до 5 м  | Смещение грунтов оснований  | Площадь смещающейся массы менее 10000 м  | II  |\n| Обвалы, движущиеся и приостановившиеся  | Объем обвалившихся горных пород  | Более 1000 м  | I  |\n|  |  | 50-1000 м  | II  |\n|  |  | Менее 50 м  | III  |\n| Сели, лавины снежно-каменные и щебенисто-глыбовые на склонах крутизной:  |  |  |  |\n| - более или равной 35°  | Ударное, гидродинамическое воздействие  | Ударная сила потока - 100 т/м и более  | I  |\n| - менее 35°  |  | Ударная сила потока - в диапазоне 100 т/м - 30 т/м  | II  |\n| - менее 35°  |  | Ударная сила потока - менее 30 т/м  | III  |',
#   'chunkSize': 150,
#   'tables': ['b8a7833ddc27c6cab45acb7f97443b80']},
#  {'text': '| Размывы берегов, склонов, русел  | На площадке размещения ОИАЭ:  | Перемещения линии среза и бровки абразионного уступа 1 м/год и более  | I  |\n|  | повреждения и трещины зданий и сооружений, оседания, провалы грунтовых оснований  | Перемещения линии среза и бровки абразионного уступа менее 1 м/год, но 0,1 м/год и более  | II  |\n|  |  | Перемещения линии среза и бровки абразионного уступа менее 0,1 м/год  | III  |\n| Оседания и провалы территории, размывы подземные, в том  | На площадке размещения ОИАЭ:  | Наличие 1 провала или более на площади 10 км и менее  | I  |\n| числе проявления карбонатного карста  | оседания, провалы грунтовых оснований  | Наличие 1 провала на площади 100 км  | II  |\n| Мерзлотно-геологические (криогенные) процессы  | Деформации грунтовых оснований  | Смещения с амплитудой 0,3 м и более  | I  |\n| \xa0(морозное пучение, вытаивание жильных  |  | Смещения с амплитудой менее 0,3 м, но более 0,1 м  | II  |\n| льдов, наледи)  |  | Смещения с амплитудой 0,1 м и менее  | III  |',
#   'chunkSize': 176,
#   'tables': ['b72cdcd0fb7f81f1719747ae802785e7']},
#  {'text': '| Деформации специфических грунтов в результате развития природных и техногенных процессов (разжижение, набухание, суффозионные химические процессы, просадки)  | Деформации грунтовых оснований  | Для площадки в проекте должны приниматься максимально возможные значения, определенные расчетом  | II  |\n| Эоловые процессы (дефляция, перевевание, барханообразование)  | Изменение рельефа под действием ветра Формирование аккумулятивных форм (например, барханы) и денудационных форм (например, рвы выдувания вдоль дорог в пустыне)  | Наличие эоловых процессов на площадке  | II  |\n| Эрозионные процессы (оврагообразование)  | Разрушение горных пород и почв поверхностными водными потоками, включающее в себя \xa0отрыв и вынос обломков материала и их переотложением  | Наличие процессов оврагообразования на площадке  | II  |\n| Коррозионная агрессивность грунтов  | Разрушение строительных материалов (зданий,  | Высокая коррозионная агрессивность  | I  |\n| и подземных вод  | сооружений), оборудования,  | Средняя коррозионная агрессивность  | II  |\n|  | трубопроводов, кабелей  | Низкая коррозионная агрессивность  | III  |\n| Глубина залегания уровня грунтовых вод  | Деформации грунтов основания, зданий и сооружений  | Глубина залегания уровня грунтовых вод менее 3 м от поверхности планировки в грунтах мощностью 10 м и более с коэффициентом фильтрации 10 м/сутки и более  | I  |',
#   'chunkSize': 188,
#   'tables': ['affa5ab03bf8d4757dc938a1167c89e0']},
#  {'text': '| Климатическая (солнечная) термодеструкция  | Повреждение неметаллических материалов и ЛКП при сроке эксплуатации АС более 30 лет на территории тропиков и субтропиков  | Температурно-влажностные характеристики климатических условий: влажность воздуха; среднегодовая температура воздуха; среднесуточная температура поверхности; - перегрев; среднегодовая солнечная радиация. Учитывается влияние отдельных агрессивных факторов, и их совместное ускоряющее воздействие на долговечность материала. Определяется расчетом  | II  |\n| III. Факторы, создающие внешние воздействия техногенного происхождения (техногенные факторы)  |\n| Падение летательного аппарата и других  | Удар, разлив топлива, возгорание топлива,  | Возможная масса аппарата более 20 т  | I  |\n| летящих предметов  | пожар  | Возможная масса аппарата 5 т и более, но менее или равна 20 т  | II  |\n|  |  | Возможная масса аппарата менее 5 т  | III  |\n| Пожар по внешним причинам  | Опасные факторы пожара (дым,  | Воздействие на ОИАЭ более 2 ч  | I  |\n|  | повышение температуры окружающей среды, токсичные продукты, горение термического разложения, пониженная концентрация кислорода)  | То же, но воздействие на ОИАЭ 2 ч и менее  | II  |',
#   'chunkSize': 173,
#   'tables': ['e657123d4d9a94cd5b0231b2443ade16']},
#  {'text': '| Взрыв на объекте  | ВУВ, летящие предметы, дым, газ, пыль, сопутствующие пожары  | Давление во фронте ВУВ на здания и сооружения ОИАЭ 30 кПа и более  | I  |\n|  |  | Давление во фронте ВУВ на здания и сооружения ОИАЭ менее 30 кПа, но более или равно 1 кПа  | II  |\n|  |  | Давление во фронте ВУВ на здания и сооружения ОИАЭ менее 1 кПа  | III  |\n| Выбросы взрывоопасных, воспламеняющихся  | ВУВ, летящие предметы, дым, газ, пыль, сопутствующие пожары,  | Давление во фронте ВУВ на здания и сооружения ОИАЭ 30 кПа и более  | I  |\n| газов и аэрозолей в атмосферу, взрыв дрейфующих облаков  | колебания грунта  | Давление во фронте ВУВ на здания и сооружения ОИАЭ менее 30 кПа, но более или равно 1 кПа  | II  |\n|  |  | Давление во фронте ВУВ на здания и сооружения ОИАЭ менее 1 кПа  | III  |\n| Выбросы токсичных паров, газов и аэрозолей в атмосферу  | Повышение концентрации токсичных газов и аэрозолей  | Расчетные параметры превышают нормативные предельно допустимые значения  | II  |\n|  |  | Расчетные параметры ниже нормативных предельно допустимых значений  | III  |',
#   'chunkSize': 194,
#   'tables': ['b1b6180c1eb3c3413b41a1b3029f5cf7']},
# ...
#   'chunkSize': 199,
#   'tables': ['dec37560eb8450bed12db40de0291ab0']},
#  {'text': '| Коррозионная агрессивность грунтов и подземных вод  | Характеристики коррозионной агрессивности грунтов и подземных вод, определенные на основе рекомендаций соответствующих строительных сводов правил  |\n| Глубина залегания уровня грунтовых вод  | Глубина залегания уровня грунтовых вод от поверхности планировки. \xa0\xa0\xa0\xa0\xa0Мощность водоносного горизонта. \xa0\xa0\xa0\xa0\xa0Коэффициент фильтрации, м/сутки  |\n| Биологические явления  | Воздействия микроорганизмов, растений и животных на безопасность зданий, сооружений ОИАЭ и на безопасность технологических процессов на ОИАЭ  |\n| III. Техногенные факторы  |\n| Падение летательного аппарата и других летящих предметов  | Вероятности падения летательных аппаратов или других летящих предметов различных классов на данную площадь за срок эксплуатации ОИАЭ: жесткостные характеристики соударяемых тел; массы тел; масса топлива; скорость удара; угол соударения с конструкцией; направление воздействия; площадь соударения; точка приложения  |\n| Пожар по внешним причинам  | Вероятность возникновения пожара. \xa0\xa0\xa0\xa0\xa0Вероятность и скорость распространения пожара в направлении ОИАЭ Эквивалентная площадь поверхности, пораженной огнем Тепловой поток в источнике пожара и его изменения по направлению к ОИАЭ Расстояние от ОИАЭ Скорость и направление ветра \xa0\xa0\xa0\xa0\xa0Мощность источника зажигания  |\n| Взрыв на объекте  | Избыточное давление во фронте ВУВ Тротиловый эквивалент Расстояние до ОИАЭ Расчетная концентрация, токсичность газа возле ОИАЭ Вероятность дрейфа взрывоопасного облака по направлению к ОИАЭ, вероятность возгорания облака  |',
#   'chunkSize': 198,
#   'tables': ['fdfa2704469dd6bff72b8f414ff4e7d6']},
#  {'text': '| Выбросы взрывоопасных, воспламеняющихся газов и аэрозолей в атмосферу, взрыв дрейфующих облаков  | Начальная концентрация в месте выброса.Рассеивание выбросов в атмосфере Концентрация от первичных источников и вторичных эффектов поражения, как функция времени с учетом нормативного забора и выпуска воздуха Продолжительность воздействия  |\n| Выбросы токсичных паров, газов и аэрозолей в атмосферу  | Начальная концентрация в месте выброса Рассеивание выбросов в атмосфере Концентрация от первичных источников и вторичных эффектов поражения, как функция времени с учетом нормативного забора и выпуска воздуха Продолжительность воздействия  |\n| Радиационная авария  | Возможные аварии на объекте или вне его границ, приводящие к необходимости принятия мер защиты работников (персонала) в начальном периоде радиационной аварии Количество радиоактивных веществ, поступивших в окружающую среду Дозы, полученные работниками (персоналом)  |\n| Коррозионные жидкие сбросы в поверхностные и грунтовые воды  | Начальная концентрация Концентрация коррозионных сред, взаимодействующих с системами ОИАЭ, как функция времени и расстояния Продолжительность воздействия Повреждаемость системы за год эксплуатации и за срок эксплуатации Расстояние от источника выброса, от места выброса до ОИАЭ  |\n| Электромагнитные импульсы и излучения  | Напряженность электрического и магнитного полей  |',
#   'chunkSize': 176,
#   'tables': ['424f43b661a0300c31d04300af64dcb6']},
#  {'text': '| Разлив масел и нефтепродуктов на прибрежных поверхностях водных объектов  | Площадь пятна, толщина слоя Химический состав Расстояние до ОИАЭ Расстояние до места водозабора ОИАЭ Тепловой поток в источнике пожара и его изменения по направлению к ОИАЭ Концентрация масел и нефти в месте водозабора ОИАЭ  |\n| Прорыв естественных и искусственных водохранилищ  | Высота и скорость волны прорыва в районе размещения ОИАЭ Абсолютная отметка уровня и продолжительность затопления территории при сочетании неблагоприятных факторов, включая экстремальные уровни весеннего половодья или дождевых паводков водотоков в районе размещения объекта с учетом высоты волны прорыва водохранилищ  |\n\nПриложение N 7 к федеральным нормам и правилам в области использования атомной энергии "Учет внешних воздействий природного и техногенного происхождения на объекты использования атомной энергии", утвержденным приказом Федеральной службы по экологическому, технологическому и атомному надзору от 30 ноября 2017 года N 514 Краткое описание и логическая схема процедуры анализа безопасности объектов использования атомной энергии при природных и техногенных воздействиях 1. Определяются типы внешних воздействий (блок 1 из приведенных блоков 1-9). Определяются зависимости интенсивности процессов, явлений и факторов внешнего происхождения от вероятности их реализации. Определяются параметры внешних воздействий, учитываемых в проектных основах.\n\n2. Устанавливаются постулируемые состояния нормальной эксплуатации ОИАЭ (блок 2).',
#   'chunkSize': 193,
#   'tables': ['3ac9ceb0fd2ed98154f8febb097449c9']},
#  {'text': '3. Определяется перечень элементов ОИАЭ, подвергающихся воздействию, задаются их характеристики и пределы стойкости (блок 4) на основе рассмотрения возможных сценариев развития событий (блок 3).\n\n4. Определяются результаты воздействий рассматриваемых типов на здания, сооружения, системы и элементы ОИАЭ; определяется (блок 5) их повреждаемость, а также повреждаемость зданий, сооружений, систем и элементов ОИАЭ, важных для безопасности, на основе детерминистического подхода.\n\n5. Анализируется выполнение п.3.7 настоящих Правил для внешних воздействий, учитываемых в составе проектных основ (блок 6).\n\n6. Проводится вероятностный анализ безопасности ОИАЭ для внешних воздействий (блок 7) в соответствии с требованиями федеральных норм и правил в области использования атомной энергии, по результатам которого принимается решение о достаточности или недостаточности технических и организационных мер по обеспечению безопасности ОИАЭ.\n\n7. При выявлении необходимости принимаются меры по инженерной защите ОИАЭ, либо иные технические и организационные меры по обеспечению безопасности ОИАЭ, после чего необходимо повторить анализ, начиная с блока 4 для подтверждения достаточности указанных мер (блок 8).\n\n8. Дальнейшие действия не требуются, если выполняются требования п.3.7 настоящих Правил и не требуются меры по повышению безопасности в соответствии с выводами ВАБ для внешних воздействий (блок 9).\n\nЛогическая схема анализа безопасности ОИАЭ при внешних воздействиях\n\n|  |',
#   'chunkSize': 189,
#   'tables': ['212bc110b99b6f1f1a2fea5e4267ac7a']},
#  {'text': 'Приложение N 8 к федеральным нормам и правилам в области использования атомной энергии "Учет внешних воздействий природного и техногенного происхождения на объекты использования атомной энергии", утвержденным приказом Федеральной службы по экологическому, технологическому и атомному надзору от 30 ноября 2017 года N 514 (справочное) Перечень организационных и технических мер по инженерной защите объекта использования атомной энергии от внешних воздействий А Перечень технических мер по инженерной защите, принимаемых на площадке размещения ОИАЭ 1. Регулирование уровня поверхностных и подземных вод.\n\n2. Строительство защитных сооружений, предохраняющих склоны и откосы от размыва, воздействия оползневых, обвальных и других процессов.\n\n3. Устройство подпорных стен, контрфорсов, свайных рядов и других удерживающих сооружений, предотвращающих смещение земляных масс.\n\n4. Создание русловых гидротехнических, селезадерживающих и селеотводящих сооружений.\n\n5. Дренаж подземных вод.\n\n6. Укрепление грунтов под фундаментами сооружений.\n\n7. Молниезащита зданий, сооружений и промышленных коммуникаций.\n\n8. Активная защита от коррозии подземных элементов зданий, сооружений и коммуникаций.\n\n9. Устройство защитных сооружений от летящих предметов при смерче.\n\n10. Сооружение смерчезащитных устройств в открытых бассейнах систем безопасности для ограничения уноса воды из них смерчем сверх допустимых пределов.\n\n11. Устройство преград на пути распространения ВУВ.',
#   'chunkSize': 179,
#   'tables': []},
#  {'text': '12. Обваловывание или устройство рвов вокруг территории площадки размещения ОИАЭ, устройство противопожарных разрывов и преград для исключения распространения пожара по внешним причинам.\n\nБ Перечень организационных и технических мер по инженерной защите ОИАЭ от внешних воздействий 1. Перечень организационных и технических мер по инженерной защите ОИАЭ от внешних воздействий, как правило, должен включать: размещение ОИАЭ на площадке, на которой отсутствуют процессы, явления и факторы природного и техногенного происхождения, не допускающие размещение ОИАЭ; организационные и технические меры по обеспечению безопасности при наличии на площадке неблагоприятных процессов, явлений и факторов природного и техногенного происхождения; проектирование устойчивых систем "сооружение-основание"; обеспечение устойчивости сооружений к экстремальным динамическим нагрузкам (от ураганов, землетрясений); снижение уровня динамических нагрузок, передаваемых системой "грунт-фундамент-сооружение" на реактор, технологическое и электротехническое оборудование и других важных для безопасности строительных конструкций, систем и элементов ОИАЭ; обеспечение защиты систем и элементов от динамических воздействий.',
#   'chunkSize': 137,
#   'tables': []},
#  {'text': '2. В качестве типовых сейсмо-, ударо- и виброзащитных мероприятий рекомендуется: повышение жесткости конструктивных элементов строительных конструкций, оборудования, узлов крепления, а также применение устройств раскрепления оборудования, конструкций, трубопроводов; снижение динамических инерционных нагрузок, действующих на элементы объекта, путем сейсмоизоляции зданий, сооружений, конструкций и отдельных помещений, а также оборудования, трубопроводов, инженерных коммуникаций; ограничение взаимных относительных смещений и деформаций элементов оборудования, конструкций, трубопроводов с целью исключения недопустимых деформаций и соударений путем применения специальных ограничителей, компенсаторов деформаций, сейсмоизоляторов и демпферов.\n\nПеречисленные мероприятия могут проводиться выборочно или в комплексе.\n\nИспользование сейсмоизоляторов или демпферов должно быть обосновано в проекте: расчетом эффективности их использования; экспериментальной проверкой предлагаемых устройств или данными испытаний их аналогов.\n\nСледует использовать прошедшие экспериментальную проверку и апробацию сейсмоизоляторы. Предпочтение следует отдавать устройствам, обеспечивающим независимую трехкомпонентную сейсмоизоляцию и некритичным к амплитудно-частотным характеристикам воздействия.',
#   'chunkSize': 127,
#   'tables': []},
#  {'text': '3. Устойчивость объекта к нагрузкам падающих летательных аппаратов и других летящих предметов обеспечивается за счет: увеличения площади сечений элементов защитных сооружений, процента их армирования, применения ударостойких материалов; улучшенной компоновки объекта, резервирования систем, важных для безопасности, применения физического разделения друг от друга систем безопасности; применения высокочастотных гасителей колебаний, устанавливаемых на системах нормальной эксплуатации и системах, важных для безопасности; обеспечения надежных средств пожаротушения; принятия технических и организационных мер по защите от вторичного эффекта при ударе летящих предметов (устройство защитных преград); применения "жертвенных" конструкций или устройств.\n\n4. Защита ОИАЭ от опасности аварийных внешних взрывов может решаться путем удаления или экранирования источника взрыва или упрочения конструкций, зданий, сооружений ОИАЭ (увеличения жесткостных и инерционных характеристик сечений).',
#   'chunkSize': 111,
#   'tables': []},
#  {'text': '5. Для эффективного повышения пожаробезопасности с целью защиты от пожаров по внешним причинам в проекте необходимо предусматривать: резервирование систем (элементов), важных для безопасности, позволяющее им выполнять свои функции при пожаре; дополнительные защитные барьеры; пространственное и физическое разделение систем безопасности, их каналов и управляющих систем безопасности; защиту систем останова и расхолаживания реакторной установки от опасных факторов пожара и обеспечения выполнения этими системами проектных функций во время и после пожара; рациональные компоновочные решения объекта; разделение технологического оборудования, кабельных линий, трубопроводов и вентиляционных потоков противопожарными преградами (барьерами) и безопасными расстояниями для исключения одновременного воздействия пожара на основное и резервное оборудование; достаточную толщину бетонных конструкций; применение огнестойких материалов, выполнение требований к противопожарной защите конструкций, помещений, зданий, частей зданий в зависимости от их огнестойкости и(или) пожарной опасности; системы пожаротушения, включая системы внутреннего и наружного противопожарного водопровода; регулирование мест и количества размещаемых на площадке ОИАЭ горючих взрыво- и пожароопасных смесей и веществ; применение надежных комплексов автоматических стационарных систем пожаротушения для ликвидации и активной локализации пожара; систем оповещения и оперативного привлечения пожарных частей, применение автоматических установок (систем) пожарной сигнализации, оповещение работников (персонала) о пожаре.\n\nСистемы вентиляции следует проектировать с учетом постулируемого внешнего пожара.',
#   'chunkSize': 186,
#   'tables': []},
#  {'text': '6. Защита систем от коррозионных жидких сбросов может быть обеспечена за счет: применения коррозионно-стойких материалов, защитных покрытий; увеличения толщин стенок трубопроводов, оборудования; применения защитных герметичных корпусов для электронного оборудования и приборов; применения детекторов коррозионного газа, регламентирующих работу запорных клапанов; контроля химического состава воды для охлаждения.\n\n7. Для предупреждения опасности от вредных (загрязняющих) веществ применяются средства: обнаружения токсичности; снижения объема и концентрации в атмосфере от вредных (загрязняющих) веществ (вентиляция, геометрическое разделение потока); индивидуальной защиты.\n\n8. Для защиты от ударов молнии, электромагнитных импульсов и излучений применяются: экраны, оптимальное пространственное размещение систем молниезащиты; молниеотводы, разрядники, заземление отдельных частей систем ОИАЭ; устройства, препятствующие перенапряжению в наиболее ответственных местах; защита вводов в сооружение, по которым возможно проникновение наводимых токов и напряжений.\n\n9. В целях защиты ОИАЭ от попадания в системы водоснабжения масел и нефтепродуктов осуществляется: оснащение водозаборов средствами обнаружения масел и нефтепродуктов; расположение водозаборных сопел под водной поверхностью.\n\n10. В целях защиты ОИАЭ от попадания в системы водоснабжения представителей флоры и фауны осуществляется: оснащение водозаборов отпугивающими средствами и средствами, препятствующими попаданию представителей флоры и фауны.\n\n11. Создание градобойной службы при размещении ОИАЭ в градоопасных районах.',
#   'chunkSize': 180,
#   'tables': []},
#  {'text': 'Электронный текст документа подготовлен АО "Кодекс" и сверен по: Официальный интернет-портал правовой информации www.pravo.gov.ru, 27.12.2017, N 0001201712270048 Об утверждении федеральных норм и правил в области использования атомной энергии "Учет внешних воздействий природного и техногенного происхождения на объекты использования атомной энергии" (Источник: ИСС "ТЕХЭКСПЕРТ")',
#   'chunkSize': 43,
#   'tables': []}]

# %%
for i in tess:
    if i["chunkSize"] > 120:
        print(i)

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification

model_name = "cointegrated/rubert-base-cased-nli-threeway"
local_dir = "./model/lr"

# Скачивает модель в указанную директорию
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)

tokenizer.save_pretrained(local_dir)
model.save_pretrained(local_dir)

print("Saved to:", local_dir)
# Out:
# Saved to: ./model/lr
